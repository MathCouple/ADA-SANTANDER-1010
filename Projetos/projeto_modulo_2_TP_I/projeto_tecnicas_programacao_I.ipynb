# %% [markdown]
# # Projeto de Técnicas de Programação I
# Você trabalha em uma consultoria de dados que foi contratada para realizar a distribuição de materiais didáticos nas escolas da cidade do Rio de Janeiro. Sua missão é realizar tratamentos nos dados de acordo com as normas de padrão definidas pelo cliente e encontrar qual a melhor rota que um caminhão deve realizar para entregar os materiais didáticos de forma a otimizar o seu percurso.
#
# * Para esse projeto você recebeu três arquivos:
#
# escolas.csv: contém os dados das escolas. [Baixe o dataset aqui;](https://s3-sa-east-1.amazonaws.com/lcpi/5c790ffd-ddeb-4cfa-a2a1-f2fc3fbc2016.csv)
#
# subprefeituras.csv: contém dados de quais bairros pertem a cada subprefeitura. [Baixe o dataset aqui;](https://s3-sa-east-1.amazonaws.com/lcpi/2c9f4b63-b826-4c89-b681-a741081a493a.csv)
#
# material_didatico.csv: contém a quantidade de material didático que cada escola deve receber. [Baixe o dataset aqui.](https://s3-sa-east-1.amazonaws.com/lcpi/005c3bc7-11e5-4075-a473-d26893619284.csv)
#
# * Como produto final, você deve entregar:
#
# Um arquivo csv no qual as linhas já estarão ordenas de acordo com a rota a ser seguida.
#
# Além disso, os dados devem estar no padrão especificado abaixo e contendo as seguintes colunas: id da escola, nome da escola, tipo da escola (EM, CIEP ou colégio), logradouro da entrega, número, bairro, subprefeitura, latitude, longitude e quantidade de material didático que deve ser entregue.
#
# O logradouro da escola deve estar em uma coluna diferente do número;
#
# Um arquivo csv com a quantidade total de material escolar por subprefeitura para que sejam contabilizados os custos por subprefeitura.
#
# * Como padrão dos dados, considere:
#
# nome das colunas em snake_case;
#
# strings não devem conter acentos;
#
# todas as strings devem estar em maiúsculo;
#
# padronização do nome dos logradouros sem abreviação (Ex: R. deve estar como Rua);
#
# latitude e longitude devem conter apenas 5 casas decimais;
#
# os ids da escola devem todos ser strings com 3 caracteres (Ex: '024');
#
# * Desafio:
#
# Entregar um plot com a representação da melhor rota que você encontrou, por exemplo:
#
# ![](Https://s3-sa-east-1.amazonaws.com/lcpi/b888027e-95e8-48e5-a6ac-07ca0be68fc4.png)

# %% [markdown]
#  Grupo 5
#  * Caroline Pereira Brum
#  * Celso Boulhosa Romero Filho Celso
#  * Ivan Borges
#  * Marcello Dias Moreira Da Silva

# %% [markdown]
# carregando e lendos os arquivos

# %%
# Importando bibliotecas
import pandas as pd
import math
import re
from unidecode import unidecode

# %%
# Carregando os dados
escolas_df = pd.read_csv('csv_raw/escolas.csv', encoding='utf-8')
subprefeituras_df = pd.read_csv('csv_raw/subprefeituras.csv', encoding='utf-8')
material_didatico_df = pd.read_csv('csv_raw/material_didatico.csv', encoding='utf-8')

# %%
escolas_df.head()
# Out:
#     id                               Escolas_Postos         BAIRRO  \
# 0  178  CENTRO INTEGRADO DE EDUCAÇÃO PÚBLICA HENFIL           CAJU
# 1  634                   EM ALICE DO AMARAL PEIXOTO        BENFICA
# 2  483                           EM CELESTINO SILVA         CENTRO
# 3  476            ESCOLA MUNICIPAL FLORIANO PEIXOTO  SÃO CRISTÓVÃO
# 4  132                            EM PEREIRA PASSOS   RIO COMPRIDO
#
#                             ENDEREÇO          lat         lon
# 0               Rua Carlos Seidl S/Nº  -22,880888  -43,225326
# 1                       Rua Ébano 187  -22,889574  -43,236202
# 2                  R. do Lavradio, 56  -22,909293  -43,183579
# 3                  Praça Argentina 20  -22,897629  -43,227456
# 4  Praça Condessa Paulo de Frontin 45  -22,924412  -43,208579

# %%
subprefeituras_df.head()
# Out:
#            nome subprefeitura
# 0  Santo Cristo        Centro
# 1        Gamboa        Centro
# 2         Saúde        Centro
# 3          Caju        Centro
# 4        Centro        Centro

# %%
material_didatico_df.head()
# Out:
#     id Quantidade
# 0  178         20
# 1  634        121
# 2  483        220
# 3  476        190
# 4  132         67

# %%
# Fazendo backup dos dados
escolas = escolas_df
subprefeituras = subprefeituras_df
material_didatico = material_didatico_df

# %%
escolas
# Out:
#       id                               Escolas_Postos             BAIRRO  \
# 0    178  CENTRO INTEGRADO DE EDUCAÇÃO PÚBLICA HENFIL               CAJU
# 1    634                   EM ALICE DO AMARAL PEIXOTO            BENFICA
# 2    483                           EM CELESTINO SILVA             CENTRO
# 3    476            ESCOLA MUNICIPAL FLORIANO PEIXOTO      SÃO CRISTÓVÃO
# 4    132                            EM PEREIRA PASSOS       RIO COMPRIDO
# ..   ...                                          ...                ...
# 147  474                  EM ENGENHEIRO GASTÃO RANGEL          GUARATIBA
# 148  301                           EM JONATAS SERRANO          GUARATIBA
# 149  215                          E.M. NARCISA AMALIA  ILHA DE GUARATIBA
# 150  606                        EM PROFESSOR CASTILHO  ILHA DE GUARATIBA
# 151   69           ESCOLA MUNICIPAL CARDEAL ARCOVERDE          MADUREIRA
#
#                               ENDEREÇO          lat         lon
# 0                 Rua Carlos Seidl S/Nº  -22,880888  -43,225326
# 1                         Rua Ébano 187  -22,889574  -43,236202
# 2                    R. do Lavradio, 56  -22,909293  -43,183579
# 3                    Praça Argentina 20  -22,897629  -43,227456
# 4    Praça Condessa Paulo de Frontin 45  -22,924412  -43,208579
# ..                                  ...         ...         ...
# 147            Estrada Do Magarça 9.183   -22,98046  -43,643545
# 148          Estrada Do Mato Alto, S/Nº  -22,953163  -43,577409
# 149  Estrada Teodoreto de Camargo S/N.º  -23,009084  -43,537582
# 150              Caminho da Matriz 4406  -22,994124  -43,593683
# 151          Rua Agostinho Barbalho 401  -22,876082  -43,343369
#
# [152 rows x 6 columns]

# %%
subprefeituras
# Out:
#                    nome subprefeitura
# 0          Santo Cristo        Centro
# 1                Gamboa        Centro
# 2                 Saúde        Centro
# 3                  Caju        Centro
# 4                Centro        Centro
# ..                  ...           ...
# 159          Santa Cruz    Zona Oeste
# 160           Guaratiba    Zona Oeste
# 161  Barra de Guaratiba    Zona Oeste
# 162  Pedra de Guaratiba    Zona Oeste
# 163   Ilha de Guaratiba    Zona Oeste
#
# [164 rows x 2 columns]

# %%
material_didatico
# Out:
#       id Quantidade
# 0    178         20
# 1    634        121
# 2    483        220
# 3    476        190
# 4    132         67
# ..   ...        ...
# 146  474        320
# 147  301        335
# 148  215        NaN
# 149  606        521
# 150  590        225
#
# [151 rows x 2 columns]

# %% [markdown]
# ajustes

# %%
# Renomeando coluna "ENDEREÇO" do DataFrame 'escolas'
escolas.columns.values[3] = 'logradouro'

# Renomeando as demais colunas
escolas.rename(columns={'Escolas_Postos':'nome_escola',
                        'BAIRRO':'bairro',
                        'lat':'latitude',
                        'lon':'longitude'},
                        inplace=True)

# Convertendo strings em letras maiúsculas
escolas = escolas.applymap(lambda x: x.upper() if isinstance(x, str) else x)

escolas
# Out:
#       id                                  nome_escola             bairro  \
# 0    178  CENTRO INTEGRADO DE EDUCAÇÃO PÚBLICA HENFIL               CAJU
# 1    634                   EM ALICE DO AMARAL PEIXOTO            BENFICA
# 2    483                           EM CELESTINO SILVA             CENTRO
# 3    476            ESCOLA MUNICIPAL FLORIANO PEIXOTO      SÃO CRISTÓVÃO
# 4    132                            EM PEREIRA PASSOS       RIO COMPRIDO
# ..   ...                                          ...                ...
# 147  474                  EM ENGENHEIRO GASTÃO RANGEL          GUARATIBA
# 148  301                           EM JONATAS SERRANO          GUARATIBA
# 149  215                          E.M. NARCISA AMALIA  ILHA DE GUARATIBA
# 150  606                        EM PROFESSOR CASTILHO  ILHA DE GUARATIBA
# 151   69           ESCOLA MUNICIPAL CARDEAL ARCOVERDE          MADUREIRA
#
#                              logradouro    latitude   longitude
# 0                 RUA CARLOS SEIDL S/Nº  -22,880888  -43,225326
# 1                         RUA ÉBANO 187  -22,889574  -43,236202
# 2                    R. DO LAVRADIO, 56  -22,909293  -43,183579
# 3                    PRAÇA ARGENTINA 20  -22,897629  -43,227456
# 4    PRAÇA CONDESSA PAULO DE FRONTIN 45  -22,924412  -43,208579
# ..                                  ...         ...         ...
# 147            ESTRADA DO MAGARÇA 9.183   -22,98046  -43,643545
# 148          ESTRADA DO MATO ALTO, S/Nº  -22,953163  -43,577409
# 149  ESTRADA TEODORETO DE CAMARGO S/N.º  -23,009084  -43,537582
# 150              CAMINHO DA MATRIZ 4406  -22,994124  -43,593683
# 151          RUA AGOSTINHO BARBALHO 401  -22,876082  -43,343369
#
# [152 rows x 6 columns]

# %%
# Renomeando coluna "nome" do DataFrame 'subprefeituras'
subprefeituras.rename(columns={'nome':'bairro'}, inplace=True)

# Convertendo strings em maiúsculas
subprefeituras = subprefeituras.applymap(lambda x: x.upper() if isinstance(x, str) else x)

subprefeituras
# Out:
#                  bairro subprefeitura
# 0          SANTO CRISTO        CENTRO
# 1                GAMBOA        CENTRO
# 2                 SAÚDE        CENTRO
# 3                  CAJU        CENTRO
# 4                CENTRO        CENTRO
# ..                  ...           ...
# 159          SANTA CRUZ    ZONA OESTE
# 160           GUARATIBA    ZONA OESTE
# 161  BARRA DE GUARATIBA    ZONA OESTE
# 162  PEDRA DE GUARATIBA    ZONA OESTE
# 163   ILHA DE GUARATIBA    ZONA OESTE
#
# [164 rows x 2 columns]

# %%
# Renomeando coluna "Quantidade" do DataFrame 'material_didatico'
material_didatico.rename(columns={'Quantidade':'quantidade_material_didatico'}, inplace=True)

material_didatico
# Out:
#       id quantidade_material_didatico
# 0    178                           20
# 1    634                          121
# 2    483                          220
# 3    476                          190
# 4    132                           67
# ..   ...                          ...
# 146  474                          320
# 147  301                          335
# 148  215                          NaN
# 149  606                          521
# 150  590                          225
#
# [151 rows x 2 columns]

# %% [markdown]
# merge

# %%
# Unindo os DataFrames com base nas colunas "bairro" e "id"
df_final = escolas.merge(subprefeituras, on='bairro', how='left')
df_final = df_final.merge(material_didatico, on='id', how='left')

df_final
# Out:
#       id                                  nome_escola             bairro  \
# 0    178  CENTRO INTEGRADO DE EDUCAÇÃO PÚBLICA HENFIL               CAJU
# 1    634                   EM ALICE DO AMARAL PEIXOTO            BENFICA
# 2    483                           EM CELESTINO SILVA             CENTRO
# 3    476            ESCOLA MUNICIPAL FLORIANO PEIXOTO      SÃO CRISTÓVÃO
# 4    132                            EM PEREIRA PASSOS       RIO COMPRIDO
# ..   ...                                          ...                ...
# 147  474                  EM ENGENHEIRO GASTÃO RANGEL          GUARATIBA
# 148  301                           EM JONATAS SERRANO          GUARATIBA
# 149  215                          E.M. NARCISA AMALIA  ILHA DE GUARATIBA
# 150  606                        EM PROFESSOR CASTILHO  ILHA DE GUARATIBA
# 151   69           ESCOLA MUNICIPAL CARDEAL ARCOVERDE          MADUREIRA
#
#                              logradouro    latitude   longitude subprefeitura  \
# 0                 RUA CARLOS SEIDL S/Nº  -22,880888  -43,225326        CENTRO
# 1                         RUA ÉBANO 187  -22,889574  -43,236202        CENTRO
# 2                    R. DO LAVRADIO, 56  -22,909293  -43,183579        CENTRO
# 3                    PRAÇA ARGENTINA 20  -22,897629  -43,227456        CENTRO
# 4    PRAÇA CONDESSA PAULO DE FRONTIN 45  -22,924412  -43,208579        CENTRO
# ..                                  ...         ...         ...           ...
# 147            ESTRADA DO MAGARÇA 9.183   -22,98046  -43,643545    ZONA OESTE
# 148          ESTRADA DO MATO ALTO, S/Nº  -22,953163  -43,577409    ZONA OESTE
# 149  ESTRADA TEODORETO DE CAMARGO S/N.º  -23,009084  -43,537582    ZONA OESTE
# 150              CAMINHO DA MATRIZ 4406  -22,994124  -43,593683    ZONA OESTE
# 151          RUA AGOSTINHO BARBALHO 401  -22,876082  -43,343369    ZONA NORTE
#
#     quantidade_material_didatico
# 0                             20
# 1                            121
# 2                            220
# 3                            190
# 4                             67
# ..                           ...
# 147                          320
# 148                          335
# 149                          NaN
# 150                          521
# 151                          468
#
# [152 rows x 8 columns]

# %%
# Fazendo backup dos dados
merge = df_final

# %% [markdown]
# tratamentos

# %%
# Removendo linhas duplicadas e atualizar o DataFrame
df_final = df_final.drop_duplicates()

# Redefinindo o índice do DataFrame
df_final = df_final.reset_index(drop=True)

df_final
# Out:
#       id                                  nome_escola              bairro  \
# 0    178  CENTRO INTEGRADO DE EDUCAÇÃO PÚBLICA HENFIL                CAJU
# 1    634                   EM ALICE DO AMARAL PEIXOTO             BENFICA
# 2    483                           EM CELESTINO SILVA              CENTRO
# 3    476            ESCOLA MUNICIPAL FLORIANO PEIXOTO       SÃO CRISTÓVÃO
# 4    132                            EM PEREIRA PASSOS        RIO COMPRIDO
# ..   ...                                          ...                 ...
# 134  210                   EM DEBORA MENDES DE MORAES  PEDRA DE GUARATIBA
# 135  474                  EM ENGENHEIRO GASTÃO RANGEL           GUARATIBA
# 136  301                           EM JONATAS SERRANO           GUARATIBA
# 137  215                          E.M. NARCISA AMALIA   ILHA DE GUARATIBA
# 138  606                        EM PROFESSOR CASTILHO   ILHA DE GUARATIBA
#
#                              logradouro    latitude   longitude subprefeitura  \
# 0                 RUA CARLOS SEIDL S/Nº  -22,880888  -43,225326        CENTRO
# 1                         RUA ÉBANO 187  -22,889574  -43,236202        CENTRO
# 2                    R. DO LAVRADIO, 56  -22,909293  -43,183579        CENTRO
# 3                    PRAÇA ARGENTINA 20  -22,897629  -43,227456        CENTRO
# 4    PRAÇA CONDESSA PAULO DE FRONTIN 45  -22,924412  -43,208579        CENTRO
# ..                                  ...         ...         ...           ...
# 134         RUA BELCHIOR DA FONSECA 643  -23,001416  -43,638757    ZONA OESTE
# 135            ESTRADA DO MAGARÇA 9.183   -22,98046  -43,643545    ZONA OESTE
# 136          ESTRADA DO MATO ALTO, S/Nº  -22,953163  -43,577409    ZONA OESTE
# 137  ESTRADA TEODORETO DE CAMARGO S/N.º  -23,009084  -43,537582    ZONA OESTE
# 138              CAMINHO DA MATRIZ 4406  -22,994124  -43,593683    ZONA OESTE
#
#     quantidade_material_didatico
# 0                             20
# 1                            121
# 2                            220
# 3                            190
# 4                             67
# ..                           ...
# 134                          570
# 135                          320
# 136                          335
# 137                          NaN
# 138                          521
#
# [139 rows x 8 columns]

# %%
# Removendo caracteres especiais das colunas "logradouro" e "nome_escola"
df_final['logradouro'] = df_final['logradouro'].str.replace('[,.º°/]', '', regex=True)
df_final['nome_escola'] = df_final['nome_escola'].str.replace('[,.º°/]', '', regex=True)

df_final
# Out:
#       id                                  nome_escola              bairro  \
# 0    178  CENTRO INTEGRADO DE EDUCAÇÃO PÚBLICA HENFIL                CAJU
# 1    634                   EM ALICE DO AMARAL PEIXOTO             BENFICA
# 2    483                           EM CELESTINO SILVA              CENTRO
# 3    476            ESCOLA MUNICIPAL FLORIANO PEIXOTO       SÃO CRISTÓVÃO
# 4    132                            EM PEREIRA PASSOS        RIO COMPRIDO
# ..   ...                                          ...                 ...
# 134  210                   EM DEBORA MENDES DE MORAES  PEDRA DE GUARATIBA
# 135  474                  EM ENGENHEIRO GASTÃO RANGEL           GUARATIBA
# 136  301                           EM JONATAS SERRANO           GUARATIBA
# 137  215                            EM NARCISA AMALIA   ILHA DE GUARATIBA
# 138  606                        EM PROFESSOR CASTILHO   ILHA DE GUARATIBA
#
#                              logradouro    latitude   longitude subprefeitura  \
# 0                   RUA CARLOS SEIDL SN  -22,880888  -43,225326        CENTRO
# 1                         RUA ÉBANO 187  -22,889574  -43,236202        CENTRO
# 2                      R DO LAVRADIO 56  -22,909293  -43,183579        CENTRO
# 3                    PRAÇA ARGENTINA 20  -22,897629  -43,227456        CENTRO
# 4    PRAÇA CONDESSA PAULO DE FRONTIN 45  -22,924412  -43,208579        CENTRO
# ..                                  ...         ...         ...           ...
# 134         RUA BELCHIOR DA FONSECA 643  -23,001416  -43,638757    ZONA OESTE
# 135             ESTRADA DO MAGARÇA 9183   -22,98046  -43,643545    ZONA OESTE
# 136             ESTRADA DO MATO ALTO SN  -22,953163  -43,577409    ZONA OESTE
# 137     ESTRADA TEODORETO DE CAMARGO SN  -23,009084  -43,537582    ZONA OESTE
# 138              CAMINHO DA MATRIZ 4406  -22,994124  -43,593683    ZONA OESTE
#
#     quantidade_material_didatico
# 0                             20
# 1                            121
# 2                            220
# 3                            190
# 4                             67
# ..                           ...
# 134                          570
# 135                          320
# 136                          335
# 137                          NaN
# 138                          521
#
# [139 rows x 8 columns]

# %%
# Removendo acentos das strings
df_final = df_final.applymap(lambda x: unidecode(x) if isinstance(x, str) else x)

df_final
# Out:
#       id                                  nome_escola              bairro  \
# 0    178  CENTRO INTEGRADO DE EDUCACAO PUBLICA HENFIL                CAJU
# 1    634                   EM ALICE DO AMARAL PEIXOTO             BENFICA
# 2    483                           EM CELESTINO SILVA              CENTRO
# 3    476            ESCOLA MUNICIPAL FLORIANO PEIXOTO       SAO CRISTOVAO
# 4    132                            EM PEREIRA PASSOS        RIO COMPRIDO
# ..   ...                                          ...                 ...
# 134  210                   EM DEBORA MENDES DE MORAES  PEDRA DE GUARATIBA
# 135  474                  EM ENGENHEIRO GASTAO RANGEL           GUARATIBA
# 136  301                           EM JONATAS SERRANO           GUARATIBA
# 137  215                            EM NARCISA AMALIA   ILHA DE GUARATIBA
# 138  606                        EM PROFESSOR CASTILHO   ILHA DE GUARATIBA
#
#                              logradouro    latitude   longitude subprefeitura  \
# 0                   RUA CARLOS SEIDL SN  -22,880888  -43,225326        CENTRO
# 1                         RUA EBANO 187  -22,889574  -43,236202        CENTRO
# 2                      R DO LAVRADIO 56  -22,909293  -43,183579        CENTRO
# 3                    PRACA ARGENTINA 20  -22,897629  -43,227456        CENTRO
# 4    PRACA CONDESSA PAULO DE FRONTIN 45  -22,924412  -43,208579        CENTRO
# ..                                  ...         ...         ...           ...
# 134         RUA BELCHIOR DA FONSECA 643  -23,001416  -43,638757    ZONA OESTE
# 135             ESTRADA DO MAGARCA 9183   -22,98046  -43,643545    ZONA OESTE
# 136             ESTRADA DO MATO ALTO SN  -22,953163  -43,577409    ZONA OESTE
# 137     ESTRADA TEODORETO DE CAMARGO SN  -23,009084  -43,537582    ZONA OESTE
# 138              CAMINHO DA MATRIZ 4406  -22,994124  -43,593683    ZONA OESTE
#
#     quantidade_material_didatico
# 0                             20
# 1                            121
# 2                            220
# 3                            190
# 4                             67
# ..                           ...
# 134                          570
# 135                          320
# 136                          335
# 137                          NaN
# 138                          521
#
# [139 rows x 8 columns]

# %% [markdown]
# logradouro

# %%
# Dicionário de mapeamento de abreviações para nomes completos
mapeamento = {
    '^R\\b':'RUA',
    '^AV\\b':'AVENIDA',
    '^PCA\\b':'PRACA',
    '^ESTR\\b':'ESTRADA',
}

# Aplicar a padronização dos logradouros usando replace
df_final['logradouro'] = df_final['logradouro'].replace(mapeamento, regex=True)

df_final
# Out:
#       id                                  nome_escola              bairro  \
# 0    178  CENTRO INTEGRADO DE EDUCACAO PUBLICA HENFIL                CAJU
# 1    634                   EM ALICE DO AMARAL PEIXOTO             BENFICA
# 2    483                           EM CELESTINO SILVA              CENTRO
# 3    476            ESCOLA MUNICIPAL FLORIANO PEIXOTO       SAO CRISTOVAO
# 4    132                            EM PEREIRA PASSOS        RIO COMPRIDO
# ..   ...                                          ...                 ...
# 134  210                   EM DEBORA MENDES DE MORAES  PEDRA DE GUARATIBA
# 135  474                  EM ENGENHEIRO GASTAO RANGEL           GUARATIBA
# 136  301                           EM JONATAS SERRANO           GUARATIBA
# 137  215                            EM NARCISA AMALIA   ILHA DE GUARATIBA
# 138  606                        EM PROFESSOR CASTILHO   ILHA DE GUARATIBA
#
#                              logradouro    latitude   longitude subprefeitura  \
# 0                   RUA CARLOS SEIDL SN  -22,880888  -43,225326        CENTRO
# 1                         RUA EBANO 187  -22,889574  -43,236202        CENTRO
# 2                    RUA DO LAVRADIO 56  -22,909293  -43,183579        CENTRO
# 3                    PRACA ARGENTINA 20  -22,897629  -43,227456        CENTRO
# 4    PRACA CONDESSA PAULO DE FRONTIN 45  -22,924412  -43,208579        CENTRO
# ..                                  ...         ...         ...           ...
# 134         RUA BELCHIOR DA FONSECA 643  -23,001416  -43,638757    ZONA OESTE
# 135             ESTRADA DO MAGARCA 9183   -22,98046  -43,643545    ZONA OESTE
# 136             ESTRADA DO MATO ALTO SN  -22,953163  -43,577409    ZONA OESTE
# 137     ESTRADA TEODORETO DE CAMARGO SN  -23,009084  -43,537582    ZONA OESTE
# 138              CAMINHO DA MATRIZ 4406  -22,994124  -43,593683    ZONA OESTE
#
#     quantidade_material_didatico
# 0                             20
# 1                            121
# 2                            220
# 3                            190
# 4                             67
# ..                           ...
# 134                          570
# 135                          320
# 136                          335
# 137                          NaN
# 138                          521
#
# [139 rows x 8 columns]

# %%
df_final['logradouro'].unique()
# Out:
# array(['RUA CARLOS SEIDL SN', 'RUA EBANO 187', 'RUA DO LAVRADIO 56',
#        'PRACA ARGENTINA 20', 'PRACA CONDESSA PAULO DE FRONTIN 45',
#        'RUA BARAO DA TORRE 90', 'RUA EDUARDO SANTOS 38',
#        'AVENIDA PRESIDENTE VARGAS SN', 'RUA ANA NERI 192',
#        'RUA HADDOCK LOBO 148', 'RUA VISCONDE DE SILVA SN',
#        'RUA DO CATETE 77', 'AVENIDA OSWALDO CRUZ 124',
#        'AVENIDA ATLANTICA 1976', 'RUA BARAO DE IPANEMA 34',
#        'AVENIDA EPITACIO PESSOA 474', 'RUA DA MATRIZ 67',
#        'AVENIDA PASTEUR 433', 'RUA ASSUNCAO 257', 'RUA SEN CORREA',
#        'AVENIDA HEITOR BELTRAO SN', 'RUA FERREIRA PONTES 328',
#        'RUA BARAO DE UBA 331', 'RUA MAL JOFRE 74',
#        'BOULEVARD 28 DE SETEMBRO 353', 'RUA ANTONIO BASILIO 370',
#        'RUA ENES DE SOUSA 36', 'RUA OITO DE DEZEMBRO 275',
#        'RUA ALM JOAO CANDIDO BRASIL 352',
#        'AVENIDA PRESIDENTE JOAO GOULART 296', 'RUA MARTAGAO GESTEIRA SN',
#        'RUA CIRNE MAIA 109', 'RUA HUMBERTO DE CAMPOS SN',
#        'AVENIDA DOM HELDER CAMARA 6742', 'RUA VIOLETA SN',
#        'RUA ASSIS CARNEIRO 649', 'RUA ANA NERI', 'RUA CONEGO TOBIAS 116',
#        'RUA ADOLFO BERGAMINI 201', 'RUA VINTE QUATRO DE MAIO 931',
#        'PRACA FREDERICO DUVAL SN', 'RUA ALVARO SEIXAS SN',
#        'PRACA DA CONFEDERACAO SUICA SN', 'AVENIDA DOM HELDER CAMARA 1715',
#        'ESTRADA ADHEMAR BEBIANO 1870', 'RUA ANAMA 98',
#        'PRACA SOLDADO COSME DOS SANTOS 28', 'RUA CONDE DE AZAMBUJA 579',
#        'AVENIDA DOS DEMOCRATICOS 268', 'RUA VIANA DO CASTELO SN',
#        'RUA ENG MOREIRA LIMA 54', 'PRACA RAMOS FIGUEIRA 20',
#        'PRACA DANIEL LAMES SN', 'PRACA SANTA ROSALIA 100',
#        'RUA BENTO CARDOSO 130', 'PRACA BELMONTE 15', 'RUA DO COUTO 91',
#        'AVENIDA TEIXEIRA DE CASTRO 407', 'PRACA ALMEIDA GARRET SN',
#        'PRACA ELBA 1215', 'RUA PRINCIPAL SN', 'RUA ADAIL 49',
#        'AVENIDA BRASIL 4040 RUA DA VITORIA', 'RUA AGOSTINHO BARBALHO 401',
#        'AVENIDA PASTOR MARTIN LUTHER KING JR SN',
#        'ESTRADA DA CACUIA 1386', 'RUA SERENATA 40',
#        'RUA FAUSTO E CASTRO SN', 'PRACA DOS UCRANIANOS SN',
#        'PRACA NOSSA SENHORA DAS DORES SN',
#        'ESTRADA MARECHAL ALENCASTRO 4035', 'AVENIDA BRASIL 23364',
#        'RUA IBIA 105', 'RUA SD SERVINO MENGARDA 260',
#        'RUA HERCULANO PENA SN', 'AVENIDA BRAZ DE PINA 1614',
#        'RUA MAL BIBIANO COSTALAT 483-639', 'RUA JOSE CARVALHO SALGADO SN',
#        'AVENIDA DOS ITALIANOS 500', 'AVENIDA ERNANI CARDOSO 316',
#        'RUA ABILIO DOS SANTOS 170', 'ESTRADA LUIZDE CAMOES 1446',
#        'RUA EDGAR WERNECK 1565', 'RUA ACAPORI 495',
#        'RUA MINISTRO ALIOMAR BALEEIRO SN', 'ESTRADA DE JACAREPAGUA 3327',
#        'RUA IGARAPE-ACU', 'RUA ESPERANCA 387', 'RUA MAMORE 78',
#        'ESTRADA PAU DA FOME 196', 'PRACA BARAO DA TAQUARA 12',
#        'PRACA JOSE ALVES DE AZEVEDO 43', 'RUA FREI LUIZ ALEVATO SN',
#        'ESTRADA DO MAPUA SN RUA 3', 'RUA JOSE SILVA 155',
#        'AVENIDA DE SANTA CRUZ SN', 'RUA MARLIERIA SN',
#        'RUA RENATO REBECCHI SN', 'RUA DOS LIMADORES SN',
#        'ESTRADA DO ENGENHO NOVO SN', 'RUA URUQUE SN',
#        'AVENIDA DUQUE DE CAXIAS 170', 'RUA ROSA DE ALMEIDA 113',
#        'RUA GENERAL GOMES DE CASTRO 30', 'AVENIDA CANAL SN',
#        'RUA DO GOVERNO 866', 'RUA GENERAL BERNARDINO DE MATOS SN',
#        'RUA TEOFILO GUIMARAES 604', 'AVENIDA ALHAMBRA SN',
#        'ESTRADA MORICABA SN', 'PRACA SANTO ANASTACIO SN',
#        'RUA CONCHAS SN', 'RUA PEQUIA 97',
#        'RUA RIO DA PRATA R LUISA MARILAC 20',
#        'RUA VOTORANTIM SN KM 10 MENDANHA', 'RUA JOSE ALBANO SN',
#        'RUA JAIRO CORREA SN', 'RUA CONSOLACAO 138',
#        'AVENIDA CESARIO DE MELO SN', 'RUA CABO SAULO DE VASCONCELOS SN',
#        'RUA FELIPE CARDOSO 750', 'RUA DAS PALMEIRAS IMPERIAIS SN',
#        'RUA PORTO FIRME SN', 'RUA JOSE BALDINO SN',
#        'RUA SEVERIANO DAS CHAGAS SN',
#        'RUA EUDALDO GOMES DA SILVA SN CONJ URUCANIA',
#        'AVENIDA MARIO PEREIRA DOS SANTOS SN',
#        'AVENIDA CANAL 3 SN CONJ CESARAO',
#        'ESTRADA DE SEPETIBA SN BLOCO 1', 'ESTRADA DA PEDRA SN',
#        'ESTRADA DO PIAI 2075', 'RUA BELCHIOR DA FONSECA 643',
#        'ESTRADA DO MAGARCA 9183', 'ESTRADA DO MATO ALTO SN',
#        'ESTRADA TEODORETO DE CAMARGO SN', 'CAMINHO DA MATRIZ 4406'],
#       dtype=object)

# %%
# Criando uma função para quebrar o endereço e criar as colunas logradouro_entrega e numero
def quebrar_endereco(endereco):
    
    # Se o endereço contém "SN", dividimos a string em "SN" e o restante
    if 'SN' in endereco:
        partes = endereco.split('SN', 1)
        logradouro_entrega = partes[0].strip()
        numero = 'SN ' + partes[1].strip()
    else:
        # Se não contém "SN", dividimos o endereço em partes
        partes = endereco.split()
        numero = ''
        logradouro_entrega = ''

        # Procuramos pela parte que contém caracteres numéricos
        for parte in partes:
            if any(char.isdigit() for char in parte):
                numero = parte
                break

        # Se encontramos um número, o resto vai para a coluna 'logradouro_entrega'
        if numero:
            index_numero = partes.index(numero)
            logradouro_entrega = ' '.join(partes[:index_numero])
        else:
            # Se não encontramos número, o endereço inteiro vai para 'logradouro_entrega' e 'numero' é definido como "SN"
            logradouro_entrega = endereco
            numero = 'SN'

    return pd.Series([logradouro_entrega, numero], index=['logradouro_entrega', 'numero'])

# Aplicando a função ao DataFrame
df_final[['logradouro_entrega', 'numero']] = df_final['logradouro'].apply(quebrar_endereco)

df_final
# Out:
#       id                                  nome_escola              bairro  \
# 0    178  CENTRO INTEGRADO DE EDUCACAO PUBLICA HENFIL                CAJU
# 1    634                   EM ALICE DO AMARAL PEIXOTO             BENFICA
# 2    483                           EM CELESTINO SILVA              CENTRO
# 3    476            ESCOLA MUNICIPAL FLORIANO PEIXOTO       SAO CRISTOVAO
# 4    132                            EM PEREIRA PASSOS        RIO COMPRIDO
# ..   ...                                          ...                 ...
# 134  210                   EM DEBORA MENDES DE MORAES  PEDRA DE GUARATIBA
# 135  474                  EM ENGENHEIRO GASTAO RANGEL           GUARATIBA
# 136  301                           EM JONATAS SERRANO           GUARATIBA
# 137  215                            EM NARCISA AMALIA   ILHA DE GUARATIBA
# 138  606                        EM PROFESSOR CASTILHO   ILHA DE GUARATIBA
#
#                              logradouro    latitude   longitude subprefeitura  \
# 0                   RUA CARLOS SEIDL SN  -22,880888  -43,225326        CENTRO
# 1                         RUA EBANO 187  -22,889574  -43,236202        CENTRO
# 2                    RUA DO LAVRADIO 56  -22,909293  -43,183579        CENTRO
# 3                    PRACA ARGENTINA 20  -22,897629  -43,227456        CENTRO
# 4    PRACA CONDESSA PAULO DE FRONTIN 45  -22,924412  -43,208579        CENTRO
# ..                                  ...         ...         ...           ...
# 134         RUA BELCHIOR DA FONSECA 643  -23,001416  -43,638757    ZONA OESTE
# 135             ESTRADA DO MAGARCA 9183   -22,98046  -43,643545    ZONA OESTE
# 136             ESTRADA DO MATO ALTO SN  -22,953163  -43,577409    ZONA OESTE
# 137     ESTRADA TEODORETO DE CAMARGO SN  -23,009084  -43,537582    ZONA OESTE
# 138              CAMINHO DA MATRIZ 4406  -22,994124  -43,593683    ZONA OESTE
#
#     quantidade_material_didatico               logradouro_entrega numero
# 0                             20                 RUA CARLOS SEIDL    SN
# 1                            121                        RUA EBANO    187
# 2                            220                  RUA DO LAVRADIO     56
# 3                            190                  PRACA ARGENTINA     20
# 4                             67  PRACA CONDESSA PAULO DE FRONTIN     45
# ..                           ...                              ...    ...
# 134                          570          RUA BELCHIOR DA FONSECA    643
# 135                          320               ESTRADA DO MAGARCA   9183
# 136                          335             ESTRADA DO MATO ALTO    SN
# 137                          NaN     ESTRADA TEODORETO DE CAMARGO    SN
# 138                          521                CAMINHO DA MATRIZ   4406
#
# [139 rows x 10 columns]

# %%
#Removendo coluna 'logradouro'
df_final = df_final.drop('logradouro', axis=1)

df_final
# Out:
#       id                                  nome_escola              bairro  \
# 0    178  CENTRO INTEGRADO DE EDUCACAO PUBLICA HENFIL                CAJU
# 1    634                   EM ALICE DO AMARAL PEIXOTO             BENFICA
# 2    483                           EM CELESTINO SILVA              CENTRO
# 3    476            ESCOLA MUNICIPAL FLORIANO PEIXOTO       SAO CRISTOVAO
# 4    132                            EM PEREIRA PASSOS        RIO COMPRIDO
# ..   ...                                          ...                 ...
# 134  210                   EM DEBORA MENDES DE MORAES  PEDRA DE GUARATIBA
# 135  474                  EM ENGENHEIRO GASTAO RANGEL           GUARATIBA
# 136  301                           EM JONATAS SERRANO           GUARATIBA
# 137  215                            EM NARCISA AMALIA   ILHA DE GUARATIBA
# 138  606                        EM PROFESSOR CASTILHO   ILHA DE GUARATIBA
#
#        latitude   longitude subprefeitura quantidade_material_didatico  \
# 0    -22,880888  -43,225326        CENTRO                           20
# 1    -22,889574  -43,236202        CENTRO                          121
# 2    -22,909293  -43,183579        CENTRO                          220
# 3    -22,897629  -43,227456        CENTRO                          190
# 4    -22,924412  -43,208579        CENTRO                           67
# ..          ...         ...           ...                          ...
# 134  -23,001416  -43,638757    ZONA OESTE                          570
# 135   -22,98046  -43,643545    ZONA OESTE                          320
# 136  -22,953163  -43,577409    ZONA OESTE                          335
# 137  -23,009084  -43,537582    ZONA OESTE                          NaN
# 138  -22,994124  -43,593683    ZONA OESTE                          521
#
#                   logradouro_entrega numero
# 0                   RUA CARLOS SEIDL    SN
# 1                          RUA EBANO    187
# 2                    RUA DO LAVRADIO     56
# 3                    PRACA ARGENTINA     20
# 4    PRACA CONDESSA PAULO DE FRONTIN     45
# ..                               ...    ...
# 134          RUA BELCHIOR DA FONSECA    643
# 135               ESTRADA DO MAGARCA   9183
# 136             ESTRADA DO MATO ALTO    SN
# 137     ESTRADA TEODORETO DE CAMARGO    SN
# 138                CAMINHO DA MATRIZ   4406
#
# [139 rows x 9 columns]

# %%
df_final['logradouro_entrega'].unique()
# Out:
# array(['RUA CARLOS SEIDL', 'RUA EBANO', 'RUA DO LAVRADIO',
#        'PRACA ARGENTINA', 'PRACA CONDESSA PAULO DE FRONTIN',
#        'RUA BARAO DA TORRE', 'RUA EDUARDO SANTOS',
#        'AVENIDA PRESIDENTE VARGAS', 'RUA ANA NERI', 'RUA HADDOCK LOBO',
#        'RUA VISCONDE DE SILVA', 'RUA DO CATETE', 'AVENIDA OSWALDO CRUZ',
#        'AVENIDA ATLANTICA', 'RUA BARAO DE IPANEMA',
#        'AVENIDA EPITACIO PESSOA', 'RUA DA MATRIZ', 'AVENIDA PASTEUR',
#        'RUA ASSUNCAO', 'RUA SEN CORREA', 'AVENIDA HEITOR BELTRAO',
#        'RUA FERREIRA PONTES', 'RUA BARAO DE UBA', 'RUA MAL JOFRE',
#        'BOULEVARD', 'RUA ANTONIO BASILIO', 'RUA ENES DE SOUSA',
#        'RUA OITO DE DEZEMBRO', 'RUA ALM JOAO CANDIDO BRASIL',
#        'AVENIDA PRESIDENTE JOAO GOULART', 'RUA MARTAGAO GESTEIRA',
#        'RUA CIRNE MAIA', 'RUA HUMBERTO DE CAMPOS',
#        'AVENIDA DOM HELDER CAMARA', 'RUA VIOLETA', 'RUA ASSIS CARNEIRO',
#        'RUA CONEGO TOBIAS', 'RUA ADOLFO BERGAMINI',
#        'RUA VINTE QUATRO DE MAIO', 'PRACA FREDERICO DUVAL',
#        'RUA ALVARO SEIXAS', 'PRACA DA CONFEDERACAO SUICA',
#        'ESTRADA ADHEMAR BEBIANO', 'RUA ANAMA',
#        'PRACA SOLDADO COSME DOS SANTOS', 'RUA CONDE DE AZAMBUJA',
#        'AVENIDA DOS DEMOCRATICOS', 'RUA VIANA DO CASTELO',
#        'RUA ENG MOREIRA LIMA', 'PRACA RAMOS FIGUEIRA',
#        'PRACA DANIEL LAMES', 'PRACA SANTA ROSALIA', 'RUA BENTO CARDOSO',
#        'PRACA BELMONTE', 'RUA DO COUTO', 'AVENIDA TEIXEIRA DE CASTRO',
#        'PRACA ALMEIDA GARRET', 'PRACA ELBA', 'RUA PRINCIPAL', 'RUA ADAIL',
#        'AVENIDA BRASIL', 'RUA AGOSTINHO BARBALHO',
#        'AVENIDA PASTOR MARTIN LUTHER KING JR', 'ESTRADA DA CACUIA',
#        'RUA SERENATA', 'RUA FAUSTO E CASTRO', 'PRACA DOS UCRANIANOS',
#        'PRACA NOSSA SENHORA DAS DORES', 'ESTRADA MARECHAL ALENCASTRO',
#        'RUA IBIA', 'RUA SD SERVINO MENGARDA', 'RUA HERCULANO PENA',
#        'AVENIDA BRAZ DE PINA', 'RUA MAL BIBIANO COSTALAT',
#        'RUA JOSE CARVALHO SALGADO', 'AVENIDA DOS ITALIANOS',
#        'AVENIDA ERNANI CARDOSO', 'RUA ABILIO DOS SANTOS',
#        'ESTRADA LUIZDE CAMOES', 'RUA EDGAR WERNECK', 'RUA ACAPORI',
#        'RUA MINISTRO ALIOMAR BALEEIRO', 'ESTRADA DE JACAREPAGUA',
#        'RUA IGARAPE-ACU', 'RUA ESPERANCA', 'RUA MAMORE',
#        'ESTRADA PAU DA FOME', 'PRACA BARAO DA TAQUARA',
#        'PRACA JOSE ALVES DE AZEVEDO', 'RUA FREI LUIZ ALEVATO',
#        'ESTRADA DO MAPUA', 'RUA JOSE SILVA', 'AVENIDA DE SANTA CRUZ',
#        'RUA MARLIERIA', 'RUA RENATO REBECCHI', 'RUA DOS LIMADORES',
#        'ESTRADA DO ENGENHO NOVO', 'RUA URUQUE', 'AVENIDA DUQUE DE CAXIAS',
#        'RUA ROSA DE ALMEIDA', 'RUA GENERAL GOMES DE CASTRO',
#        'AVENIDA CANAL', 'RUA DO GOVERNO',
#        'RUA GENERAL BERNARDINO DE MATOS', 'RUA TEOFILO GUIMARAES',
#        'AVENIDA ALHAMBRA', 'ESTRADA MORICABA', 'PRACA SANTO ANASTACIO',
#        'RUA CONCHAS', 'RUA PEQUIA', 'RUA RIO DA PRATA R LUISA MARILAC',
#        'RUA VOTORANTIM', 'RUA JOSE ALBANO', 'RUA JAIRO CORREA',
#        'RUA CONSOLACAO', 'AVENIDA CESARIO DE MELO',
#        'RUA CABO SAULO DE VASCONCELOS', 'RUA FELIPE CARDOSO',
#        'RUA DAS PALMEIRAS IMPERIAIS', 'RUA PORTO FIRME',
#        'RUA JOSE BALDINO', 'RUA SEVERIANO DAS CHAGAS',
#        'RUA EUDALDO GOMES DA SILVA', 'AVENIDA MARIO PEREIRA DOS SANTOS',
#        'AVENIDA CANAL 3', 'ESTRADA DE SEPETIBA', 'ESTRADA DA PEDRA',
#        'ESTRADA DO PIAI', 'RUA BELCHIOR DA FONSECA', 'ESTRADA DO MAGARCA',
#        'ESTRADA DO MATO ALTO', 'ESTRADA TEODORETO DE CAMARGO',
#        'CAMINHO DA MATRIZ'], dtype=object)

# %%
df_final['numero'].unique()
# Out:
# array(['SN ', '187', '56', '20', '45', '90', '38', '192', '148', '77',
#        '124', '1976', '34', '474', '67', '433', '257', 'SN', '328', '331',
#        '74', '28', '370', '36', '275', '352', '296', '109', '6742', '649',
#        '116', '201', '931', '1715', '1870', '98', '579', '268', '54',
#        '100', '130', '15', '91', '407', '1215', '49', '4040', '401',
#        '1386', '40', '4035', '23364', '105', '260', '1614', '483-639',
#        '500', '316', '170', '1446', '1565', '495', '3327', '387', '78',
#        '196', '12', '43', 'SN RUA 3', '155', '113', '30', '866', '604',
#        '97', 'SN KM 10 MENDANHA', '138', '750', 'SN CONJ URUCANIA',
#        'SN CONJ CESARAO', 'SN BLOCO 1', '2075', '643', '9183', '4406'],
#       dtype=object)

# %% [markdown]
# latitude e longitude

# %%
# Limitando as colunas 'latitude' e 'longitude' a cinco (5) caracteres após a vírgula (,)
df_final[['latitude', 'longitude']] = df_final[['latitude', 'longitude']].applymap(lambda x: f"{x.split(',')[0]},{x.split(',')[1][:5]}" if isinstance(x, str) and ',' in x else x)

df_final
# Out:
#       id                                  nome_escola              bairro  \
# 0    178  CENTRO INTEGRADO DE EDUCACAO PUBLICA HENFIL                CAJU
# 1    634                   EM ALICE DO AMARAL PEIXOTO             BENFICA
# 2    483                           EM CELESTINO SILVA              CENTRO
# 3    476            ESCOLA MUNICIPAL FLORIANO PEIXOTO       SAO CRISTOVAO
# 4    132                            EM PEREIRA PASSOS        RIO COMPRIDO
# ..   ...                                          ...                 ...
# 134  210                   EM DEBORA MENDES DE MORAES  PEDRA DE GUARATIBA
# 135  474                  EM ENGENHEIRO GASTAO RANGEL           GUARATIBA
# 136  301                           EM JONATAS SERRANO           GUARATIBA
# 137  215                            EM NARCISA AMALIA   ILHA DE GUARATIBA
# 138  606                        EM PROFESSOR CASTILHO   ILHA DE GUARATIBA
#
#       latitude  longitude subprefeitura quantidade_material_didatico  \
# 0    -22,88088  -43,22532        CENTRO                           20
# 1    -22,88957  -43,23620        CENTRO                          121
# 2    -22,90929  -43,18357        CENTRO                          220
# 3    -22,89762  -43,22745        CENTRO                          190
# 4    -22,92441  -43,20857        CENTRO                           67
# ..         ...        ...           ...                          ...
# 134  -23,00141  -43,63875    ZONA OESTE                          570
# 135  -22,98046  -43,64354    ZONA OESTE                          320
# 136  -22,95316  -43,57740    ZONA OESTE                          335
# 137  -23,00908  -43,53758    ZONA OESTE                          NaN
# 138  -22,99412  -43,59368    ZONA OESTE                          521
#
#                   logradouro_entrega numero
# 0                   RUA CARLOS SEIDL    SN
# 1                          RUA EBANO    187
# 2                    RUA DO LAVRADIO     56
# 3                    PRACA ARGENTINA     20
# 4    PRACA CONDESSA PAULO DE FRONTIN     45
# ..                               ...    ...
# 134          RUA BELCHIOR DA FONSECA    643
# 135               ESTRADA DO MAGARCA   9183
# 136             ESTRADA DO MATO ALTO    SN
# 137     ESTRADA TEODORETO DE CAMARGO    SN
# 138                CAMINHO DA MATRIZ   4406
#
# [139 rows x 9 columns]

# %%
df_final['latitude'].unique()
# Out:
# array(['-22,88088', '-22,88957', '-22,90929', '-22,89762', '-22,92441',
#        '-22,98333', '-22,91553', '-22,90712', '-22,89848', '-22,91723',
#        '-22,95916', '-22,92278', '-22,94071', '-22,96864', '-22,97482',
#        '-22,74828', '-22,98195', '-22,95270', '-22,95382', '-22,94555',
#        '-22,93398', '-22,92127', '-22,92685', '-22,91544', '-22,91854',
#        '-22,91615', '-22,92684', '-22,92906', '-22,90982', '-22,91682',
#        '-22,99369', '-22,99741', '-22,89203', '-22,98155', '-22,88133',
#        '-22,90627', '-22,89508', '-22,90070', '-22,90416', '-22,90034',
#        '-22,90303', '-22,88766', '-22,89417', '-22,87835', '-22,88531',
#        '-22,87389', '-22,81527', '-22,87757', '-22,88417', '-22,88098',
#        '-22,80944', '-22,83941', '-22,84779', '-22,89557', '-22,84562',
#        '-22,83566', '-22,84858', '-22,83896', '-22,85386', '-22,82994',
#        '-22,85713', '-22,85782', '-22,86047', '-22,87373', '-22,87608',
#        '-22,81631', '-22,80769', '-22,81244', '-22,81389', '-22,82558',
#        '-22,82636', '-22,84541', '-22,86084', '-22,84944', '-22,87429',
#        '-22,83783', '-22,87185', '-22,87221', '-22,85196', '-22,88240',
#        '-22,86459', '-22,84604', '-22,94710', '-22,96072', '-23,01981',
#        '-22,97335', '-22,97198', '-22,98172', '-22,93816', '-22,91883',
#        '-22,89693', '-22,94265', '-22,93532', '-22,92688', '-22,93253',
#        '-22,88179', '-22,85043', '-22,89252', '-22,88814', '-22,86652',
#        '-22,85894', '-22,85608', '-22,88207', '-22,86876', '-22,88345',
#        '-22,89299', '-22896931', '-22,88385', '-22,88907', '-22,92529',
#        '-22,88648', '-22,88729', '-22,91096', '-22,92315', '-22,85878',
#        '-22,89036', '-22,90858', '-22,91959', '-22,93415', '-22,88854',
#        '-22,92139', '-22,92306', '-22,92485', '-22,97173', '-22,91571',
#        '-22,91402', '-22,87318', '-22,93011', '-22,95601', '-22,97450',
#        '-22,97906', '-23,00141', '-22,98046', '-22,95316', '-23,00908',
#        '-22,99412'], dtype=object)

# %%
df_final['longitude'].unique()
# Out:
# array(['-43,22532', '-43,23620', '-43,18357', '-43,22745', '-43,20857',
#        '-43,19903', '-43,19158', '-43,19506', '-43,23775', '-43,21104',
#        '-43,19972', '-43,17668', '-43,17647', '-43,18113', '-43,18906',
#        '-43,21357', '-43,19176', '-43,16888', '-43,18659', '-43,18101',
#        '-43,22799', '-43,25491', '-43,21109', '-43,26509', '-43,24704',
#        '-43,23788', '-43,23287', '-43,23939', '-43,23692', '-43,23557',
#        '-43,27218', '-43,27992', '-43,21702', '-43,29409', '-43,30791',
#        '-43,31382', '-43,25540', '-43,28033', '-43,29594', '-43,26788',
#        '-43,30246', '-43,26384', '-43,27488', '-43,25410', '-43,27771',
#        '-43,30356', '-43,28562', '-43,26262', '-43,25324', '-43,32629',
#        '-43,30006', '-43,26144', '-43,57050', '-43,28400', '-43,28815',
#        '-43,26858', '-43,27517', '-43,25245', '-43,28210', '-43,26416',
#        '-43,24045', '-43,25428', '-43,24071', '-43,34336', '-43,34014',
#        '-43,18155', '-43,20965', '-43,37392', '-43,39207', '-43,40288',
#        '-43,37852', '-43,34455', '-43,30378', '-43,31471', '-43,31253',
#        '-43,43243', '-43,35033', '-43,34949', '-43,33811', '-43,36595',
#        '-43,33866', '-43,35973', '-43,35343', '-43,48172', '-43,32915',
#        '-43,41011', '-43,49163', '-43,34257', '-43,41625', '-43,35266',
#        '-43,33896', '-43,36972', '-43,38788', '-43,35113', '-43,48732',
#        '-43,46685', '-43,47295', '-43,47629', '-43,42514', '-43,44387',
#        '-43,38660', '-43,44644', '-43,45065', '-43,42945', '-43,44121',
#        '-43352667', '-43,41733', '-43,39248', '-43,56664', '-43,52880',
#        '-43,58735', '-43,61605', '-43,51877', '-43,53704', '-43,59399',
#        '-43,58473', '-43,54683', '-43,66213', '-43,63805', '-43,68058',
#        '-43,69233', '-43,63289', '-43,69735', '-43,67975', '-43,65343',
#        '-43,62773', '-43,65289', '-43,68674', '-43,64817', '-43,67058',
#        '-43,63875', '-43,64354', '-43,57740', '-43,53758', '-43,59368'],
#       dtype=object)

# %%
# Corrigindo valores das colunas 'longitude' e 'latitude'
df_final['longitude'] = df_final['longitude'].str.replace('-43352667', '-43,35266')
df_final['latitude'] = df_final['latitude'].str.replace('-22896931', '-22,89693')

# Substituindo vírgulas por pontos e convertendo para float
df_final['latitude'] = df_final['latitude'].str.replace(',', '.').astype(float)
df_final['longitude'] = df_final['longitude'].str.replace(',', '.').astype(float)

# %% [markdown]
# id

# %%
# Garantindo que a coluna 'id' possua 3 caracteres
df_final['id'] = df_final['id'].astype(str).str.zfill(3)

# Transformando a coluna para uma coluna de strings
df_final['id'] = df_final['id'].astype(str)

df_final
# Out:
#       id                                  nome_escola              bairro  \
# 0    178  CENTRO INTEGRADO DE EDUCACAO PUBLICA HENFIL                CAJU
# 1    634                   EM ALICE DO AMARAL PEIXOTO             BENFICA
# 2    483                           EM CELESTINO SILVA              CENTRO
# 3    476            ESCOLA MUNICIPAL FLORIANO PEIXOTO       SAO CRISTOVAO
# 4    132                            EM PEREIRA PASSOS        RIO COMPRIDO
# ..   ...                                          ...                 ...
# 134  210                   EM DEBORA MENDES DE MORAES  PEDRA DE GUARATIBA
# 135  474                  EM ENGENHEIRO GASTAO RANGEL           GUARATIBA
# 136  301                           EM JONATAS SERRANO           GUARATIBA
# 137  215                            EM NARCISA AMALIA   ILHA DE GUARATIBA
# 138  606                        EM PROFESSOR CASTILHO   ILHA DE GUARATIBA
#
#      latitude  longitude subprefeitura quantidade_material_didatico  \
# 0   -22.88088  -43.22532        CENTRO                           20
# 1   -22.88957  -43.23620        CENTRO                          121
# 2   -22.90929  -43.18357        CENTRO                          220
# 3   -22.89762  -43.22745        CENTRO                          190
# 4   -22.92441  -43.20857        CENTRO                           67
# ..        ...        ...           ...                          ...
# 134 -23.00141  -43.63875    ZONA OESTE                          570
# 135 -22.98046  -43.64354    ZONA OESTE                          320
# 136 -22.95316  -43.57740    ZONA OESTE                          335
# 137 -23.00908  -43.53758    ZONA OESTE                          NaN
# 138 -22.99412  -43.59368    ZONA OESTE                          521
#
#                   logradouro_entrega numero
# 0                   RUA CARLOS SEIDL    SN
# 1                          RUA EBANO    187
# 2                    RUA DO LAVRADIO     56
# 3                    PRACA ARGENTINA     20
# 4    PRACA CONDESSA PAULO DE FRONTIN     45
# ..                               ...    ...
# 134          RUA BELCHIOR DA FONSECA    643
# 135               ESTRADA DO MAGARCA   9183
# 136             ESTRADA DO MATO ALTO    SN
# 137     ESTRADA TEODORETO DE CAMARGO    SN
# 138                CAMINHO DA MATRIZ   4406
#
# [139 rows x 9 columns]

# %%
df_final['id'].unique()
# Out:
# array(['178', '634', '483', '476', '132', '017', '055', '490', '600',
#        '089', '387', '331', '450', '558', '413', '540', '309', '268',
#        '523', '035', '011', '226', '638', '126', '180', '163', '361',
#        '280', '060', '587', '653', '660', '382', '217', '378', '429',
#        '025', '373', '624', '157', '020', '117', '502', '351', '135',
#        '388', '440', '259', '422', '041', '537', '230', '379', '146',
#        '566', '498', '663', '121', '161', '263', '118', '140', '260',
#        '069', '090', '274', '676', '390', '608', '589', '256', '091',
#        '248', '623', '603', '673', '520', '412', '031', '514', '023',
#        '415', '016', '570', '528', '414', '690', '202', '550', '211',
#        '206', '492', '466', '636', '527', '586', '080', '398', '175',
#        '308', '576', '495', '641', '689', '171', '477', '687', '568',
#        '399', '255', '262', '616', '320', '144', '534', '342', '052',
#        '139', '323', '573', '560', '246', '319', '584', '311', '316',
#        '497', '297', '068', '515', '289', '210', '474', '301', '215',
#        '606'], dtype=object)

# %% [markdown]
# nome e tipo_escola

# %%
df_final['nome_escola'].unique()
# Out:
# array(['CENTRO INTEGRADO DE EDUCACAO PUBLICA HENFIL',
#        'EM ALICE DO AMARAL PEIXOTO', 'EM CELESTINO SILVA',
#        'ESCOLA MUNICIPAL FLORIANO PEIXOTO', 'EM PEREIRA PASSOS',
#        'EM PRESIDENTE JOSE LINHARES', 'EM SANTA CATARINA', 'EM TIA CIATA',
#        'EM URUGUAI', 'EM MARIO CLAUDIO', 'CIEP PRESIDENTE AGOSTINHO NETO',
#        'CIEP TANCREDO NEVES', 'EM ALBERTO BARTH', 'EM CICERO PENA',
#        'EM COCIO BARCELOS', 'EM HENRIQUE DODSWORTH', 'EM MEXICO',
#        'ESCOLA MUNICIPAL MINAS GERAIS', 'EM PRESIDENTE DA COSTA E SILVA',
#        'EM SENADOR CORREA', 'CIEP SAMUEL WEINER', 'EM AFRANIO PEIXOTO',
#        'EM AZEVEDO SODRE', 'EM DUQUE DE CAXIAS',
#        'ESCOLA MUNICIPAL EQUADOR', 'EM LAUDIMIA TROTTA',
#        'EM PRUDENTE DE MORAES',
#        'ESCOLA MUNICIPAL GENERAL HUMBERTO DE SOUZA MELLO',
#        'ESCOLA MUNICIPAL BARAO HOMEM DE MELO', 'EM ALMIRANTE TAMANDARE',
#        'EM LUCIA MIGUEL PEREIRA', 'EM NOSSA SENHORA DA POMPEIA',
#        'EM SANTOS ANJOS', 'EM ALAGOAS', 'EM BRIGADEIRO FARIA LIMA',
#        'EM FELIX PACHECO', 'ESCOLA MUNICIPAL GEORGE SUMMER',
#        'EM PROFESSOR AUGUSTO PAULINO', 'EM RIO GRANDE DO SUL',
#        'EM SARMIENTO', 'EM TAGORE', 'CIEP CHANCELER WILLY BRANDT',
#        'CIEP PATRICE LUMUMBA',
#        'CENTRO INTEGRADO DE EDUCACAO PUBLICA VINICIUS DE MORAES',
#        'EM DOMINGOS BEBIANO', 'EM CARDEAL CAMARA', 'EM JOAQUIM RIBEIRO',
#        'EM PERNAMBUCO', 'ESCOLA MUNICIPAL ALBINO SOUZA CRUZ',
#        'EM ANDRADE NEVES', 'EM ARY QUINTELLA', 'EM BERLIM',
#        'CIEP NELSON MANDELA', 'EM BERNARDO VASCONCELOS', 'EM BRANT HORTA',
#        'EM CHILE', 'EM CIENTISTA MARIO KROEFF', 'EM DILERMANDO CRUZ',
#        'EM JOAO DE DEUS', 'EM PADRE MANUEL DE NOBREGA',
#        'CENTRO INTEGRADO DE EDUCACAO PUBLICA ELIS REGINA',
#        'EM PEDRO LESSA', 'EM PROFESSOR JOSUE DE CASTRO',
#        'ESCOLA MUNICIPAL CARDEAL ARCOVERDE', 'EM THOMAS JEFFERSON',
#        'EM ABEILARD FEIJO', 'ESCOLA MUNICIPAL ANISIO TEIXEIRA',
#        'EM ANDREA FONTES PEIXOTO', 'EM GRANDJEAN DE MONTIGNY',
#        'EM MARIO PIRAGIBE', 'ESCOLA MUNICIPAL PARAIBA', 'EM PIAUI',
#        'EM ASPIRANTE CARLOS ALFREDO', 'EM CECILIA MEIRELES',
#        'EM ESPIRITO SANTO', 'ESCOLA MUNICIPAL GRECIA',
#        'EM BARONESA DE SAAVEDRA', 'EM MOZART LAGO', 'EM PARA',
#        'EM PARANA', 'EM CERVANTES', 'ESCOLA MUNICIPAL LUIZ DE CAMOES',
#        'CIEP JOAO BATISTA DOS SANTOS', 'EM HELENA LOPES ABRANCHES',
#        'CIEP MARGARET MEE', 'EM CLAUDIO BESSERMAN VIANNA - BUSSUNDA',
#        'ESCOLA MUNICIPAL FINLANDIA',
#        'EM PROFESSOR TEOFILO MOREIRA DA COSTA', 'EM 25 DE ABRIL',
#        'EM FRANCIS HIME', 'EM HONDURAS', 'EM MENEZES CORTES',
#        'ESCOLA MUNICIPAL NELSON RODRIGUES', 'EM PABLO NERUDA',
#        'EM VIRGILIO VARZEA', 'CIEP ANTONIO EVARISTO DE MORAES',
#        'EM JOSE MAURO DE VASCONCELOS', 'EM LEONARDO DA VINCI',
#        'EM NACOES UNIDAS', 'CIEP THOMAS JEFFERSON',
#        'EM CORYNTHO DA FONSECA', 'EM ENGENHEIRO LAFAYETTE DE ANDRADA',
#        'EM LAURO MULLER', 'EM MOACIR PADILHA',
#        'ESCOLA MUNICIPAL PADRE LEONEL FRANCA', 'EM PAULO MARANHAO',
#        'EM TASSO DA SILVEIRA', 'EM VISCONDE DE PORTO SEGURO',
#        'CIEP CLEMENTINA DE JESUS',
#        'CIEP FRANCISCO CAVALCANTE PONTES DE MIRANDA',
#        'CIEP HERIVELTO MARTINS', 'CIEP PROFESSOR DARCI RIBEIRO',
#        'COLEGIO MUNICIPAL PRESIDENTE ANTONIO CARLOS',
#        'EM ALFREDO CESARIO ALVIM', 'EM CORA CORALINA',
#        'EM FERNANDO COSTA', 'EM PROFESSOR PAULO SILVA',
#        'EM JESUS SOARES PEREIRA', 'CIEP ISMAEL NERY',
#        'CENTRO INTEGRADO DE EDUCACAO PUBLICA MAJOR MANUEL GOMES ARCHER',
#        'EM ANDRE VIDAL DE NEGREIROS', 'EM FERNANDO AZEVEDO',
#        'EM MARECHAL PEDRO CAVALCANTI', 'ESCOLA MUNICIPAL NELSON ROMERO',
#        'EM PESTALOZZI', 'EM PROFESSORA FLAVIA DOS SANTOS SOARES',
#        'EM PROFESSORA LEILA MEHL MENEZES DE MATTOS',
#        'EM PROFESSORA SILVIA DE ARAUJO TOLEDO', 'EM WALQUIR PEREIRA',
#        'CIEP HILDEBRANDO DE ARAUJO GOES', 'EM BERTHA LUTZ',
#        'EM DEBORA MENDES DE MORAES', 'EM ENGENHEIRO GASTAO RANGEL',
#        'EM JONATAS SERRANO', 'EM NARCISA AMALIA', 'EM PROFESSOR CASTILHO'],
#       dtype=object)

# %%
# Aplicando uma função lambda à coluna 'nome_escola' para gerar a coluna 'tipo_escola' e preenche-la corretamente
df_final['tipo_escola'] = df_final['nome_escola'].apply(lambda x: 'EM' if 'EM' in x or 'ESCOLA' in x else ('CIEP' if 'CIEP' in x or 'INTEGRADO' in x else 'COLEGIO'))

df_final
# Out:
#       id                                  nome_escola              bairro  \
# 0    178  CENTRO INTEGRADO DE EDUCACAO PUBLICA HENFIL                CAJU
# 1    634                   EM ALICE DO AMARAL PEIXOTO             BENFICA
# 2    483                           EM CELESTINO SILVA              CENTRO
# 3    476            ESCOLA MUNICIPAL FLORIANO PEIXOTO       SAO CRISTOVAO
# 4    132                            EM PEREIRA PASSOS        RIO COMPRIDO
# ..   ...                                          ...                 ...
# 134  210                   EM DEBORA MENDES DE MORAES  PEDRA DE GUARATIBA
# 135  474                  EM ENGENHEIRO GASTAO RANGEL           GUARATIBA
# 136  301                           EM JONATAS SERRANO           GUARATIBA
# 137  215                            EM NARCISA AMALIA   ILHA DE GUARATIBA
# 138  606                        EM PROFESSOR CASTILHO   ILHA DE GUARATIBA
#
#      latitude  longitude subprefeitura quantidade_material_didatico  \
# 0   -22.88088  -43.22532        CENTRO                           20
# 1   -22.88957  -43.23620        CENTRO                          121
# 2   -22.90929  -43.18357        CENTRO                          220
# 3   -22.89762  -43.22745        CENTRO                          190
# 4   -22.92441  -43.20857        CENTRO                           67
# ..        ...        ...           ...                          ...
# 134 -23.00141  -43.63875    ZONA OESTE                          570
# 135 -22.98046  -43.64354    ZONA OESTE                          320
# 136 -22.95316  -43.57740    ZONA OESTE                          335
# 137 -23.00908  -43.53758    ZONA OESTE                          NaN
# 138 -22.99412  -43.59368    ZONA OESTE                          521
#
#                   logradouro_entrega numero tipo_escola
# 0                   RUA CARLOS SEIDL    SN         CIEP
# 1                          RUA EBANO    187          EM
# 2                    RUA DO LAVRADIO     56          EM
# 3                    PRACA ARGENTINA     20          EM
# 4    PRACA CONDESSA PAULO DE FRONTIN     45          EM
# ..                               ...    ...         ...
# 134          RUA BELCHIOR DA FONSECA    643          EM
# 135               ESTRADA DO MAGARCA   9183          EM
# 136             ESTRADA DO MATO ALTO    SN           EM
# 137     ESTRADA TEODORETO DE CAMARGO    SN           EM
# 138                CAMINHO DA MATRIZ   4406          EM
#
# [139 rows x 10 columns]

# %%
df_final['tipo_escola'].unique()
# Out:
# array(['CIEP', 'EM', 'COLEGIO'], dtype=object)

# %% [markdown]
# bairro

# %%
df_final['bairro'].unique()
# Out:
# array(['CAJU', 'BENFICA', 'CENTRO', 'SAO CRISTOVAO', 'RIO COMPRIDO',
#        'IPANEMA', 'SANTA TERESA', 'HUMAITA', 'CATETE', 'FLAMENGO',
#        'COPACABANA', 'BOTAFOGO', 'URCA', 'LARANJEIRAS', 'TIJUCA',
#        'ANDARAI', 'PRACA DA BANDEIRA', 'GRAJAU', 'VILA ISABEL',
#        'MARACANA/ VILA ISABEL', 'MARACANA/ TIJUCA', 'VIDIGAL',
#        'SAO CONRADO', 'TODOS OS SANTOS', 'LEBLON', 'PILARES',
#        'AGUA SANTA', 'PIEDADE', 'RIACHUELO', 'MEIER', 'ENGENHO DE DENTRO',
#        'ENGENHO NOVO', 'JACARE', 'DEL CASTILHO', 'INHAUMA',
#        'PARADA DE LUCAS', 'MARIA DA GRACA', 'MANGUINHOS',
#        'JARDIM AMERICA', 'PENHA CIRCULAR', 'OLARIA', 'CAMPO GRANDE',
#        'PENHA', 'RAMOS', 'VIGARIO GERAL', 'BONSUCESSO', 'MADUREIRA',
#        'ACARI', 'CACUIA', 'JARDIM GUANABARA', 'PARQUE COLUMBIA', 'PAVUNA',
#        'ANCHIETA', 'GUADALUPE', 'TURIACU', 'VILA KOSMOS', 'CAVALCANTI',
#        'VILA DA PENHA', 'REALENGO', 'OSWALDO CRUZ', 'ROCHA MIRANDA',
#        'CASCADURA', 'BENTO RIBEIRO', 'COLEGIO', 'CIDADE DE DEUS',
#        'GARDENIA AZUL', 'RECREIO', 'RIO DAS PEDRAS', 'CAMORIM',
#        'VARGEM GRANDE', 'FREGUESIA JPA', 'TAQUARA', 'PRACA SECA',
#        'PECHINCHA', 'SENADOR CAMARA', 'BANGU', 'DEODORO', 'PADRE MIGUEL',
#        'JARDIM SULACAP', 'SENADOR VASCONCELOS', 'AUGUSTO VASCONCELOS',
#        'COSMOS', 'INHOAIBA', 'SANTA CRUZ', 'PACIENCIA', 'SEPETIBA',
#        'NOVA SEPETIBA', 'PEDRA DE GUARATIBA', 'GUARATIBA',
#        'ILHA DE GUARATIBA'], dtype=object)

# %%
# Removendo o ' ' após a '/' em alguns nomes de bairros
df_final['bairro'] = df_final['bairro'].str.replace('/ ', '/')

df_final
# Out:
#       id                                  nome_escola              bairro  \
# 0    178  CENTRO INTEGRADO DE EDUCACAO PUBLICA HENFIL                CAJU
# 1    634                   EM ALICE DO AMARAL PEIXOTO             BENFICA
# 2    483                           EM CELESTINO SILVA              CENTRO
# 3    476            ESCOLA MUNICIPAL FLORIANO PEIXOTO       SAO CRISTOVAO
# 4    132                            EM PEREIRA PASSOS        RIO COMPRIDO
# ..   ...                                          ...                 ...
# 134  210                   EM DEBORA MENDES DE MORAES  PEDRA DE GUARATIBA
# 135  474                  EM ENGENHEIRO GASTAO RANGEL           GUARATIBA
# 136  301                           EM JONATAS SERRANO           GUARATIBA
# 137  215                            EM NARCISA AMALIA   ILHA DE GUARATIBA
# 138  606                        EM PROFESSOR CASTILHO   ILHA DE GUARATIBA
#
#      latitude  longitude subprefeitura quantidade_material_didatico  \
# 0   -22.88088  -43.22532        CENTRO                           20
# 1   -22.88957  -43.23620        CENTRO                          121
# 2   -22.90929  -43.18357        CENTRO                          220
# 3   -22.89762  -43.22745        CENTRO                          190
# 4   -22.92441  -43.20857        CENTRO                           67
# ..        ...        ...           ...                          ...
# 134 -23.00141  -43.63875    ZONA OESTE                          570
# 135 -22.98046  -43.64354    ZONA OESTE                          320
# 136 -22.95316  -43.57740    ZONA OESTE                          335
# 137 -23.00908  -43.53758    ZONA OESTE                          NaN
# 138 -22.99412  -43.59368    ZONA OESTE                          521
#
#                   logradouro_entrega numero tipo_escola
# 0                   RUA CARLOS SEIDL    SN         CIEP
# 1                          RUA EBANO    187          EM
# 2                    RUA DO LAVRADIO     56          EM
# 3                    PRACA ARGENTINA     20          EM
# 4    PRACA CONDESSA PAULO DE FRONTIN     45          EM
# ..                               ...    ...         ...
# 134          RUA BELCHIOR DA FONSECA    643          EM
# 135               ESTRADA DO MAGARCA   9183          EM
# 136             ESTRADA DO MATO ALTO    SN           EM
# 137     ESTRADA TEODORETO DE CAMARGO    SN           EM
# 138                CAMINHO DA MATRIZ   4406          EM
#
# [139 rows x 10 columns]

# %% [markdown]
# quantidade_material_didático

# %%
df_final['quantidade_material_didatico'].unique()
# Out:
# array(['20', '121', '220', '190', '67', '48', '92', '578', '591', '473',
#        '456', '223', '420', '573', "''", '516', '319', '308', '111',
#        '525', '445', '164', '293', '399', '185', '576', '63', '491',
#        "'NaN'", '336', '159', '342', '262', '440', '365', nan, '183',
#        '44', '109', '350', '255', '457', '493', '489', '504', '530',
#        '158', '123', '468', '234', '24', '151', '564', '61', '426', '167',
#        '509', '292', '210', '153', "'397'", '561', '180', '257', '260',
#        '317', '345', '513', '416', '352', '393', '136', "'395'", '115',
#        '534', '152', '430', '466', '51', '26', '94', '128', '520', '392',
#        '279', '161', '179', '194', '599', '315', '435', '400', '148',
#        '269', '571', '235', '187', '362', '71', '221', '372', '479', '99',
#        '157', '296', '330', '316', '106', '207', '459', '537', '162',
#        '579', '517', "' '", '135', '341', '329', '570', '320', '335',
#        '521'], dtype=object)

# %%
# Garantindo que a  coluna 'quantidade_material_didatico' possua somente valores numéricos
df_final['quantidade_material_didatico'] = pd.to_numeric(df_final['quantidade_material_didatico'], errors='coerce').fillna(0).astype(int)

df_final
# Out:
#       id                                  nome_escola              bairro  \
# 0    178  CENTRO INTEGRADO DE EDUCACAO PUBLICA HENFIL                CAJU
# 1    634                   EM ALICE DO AMARAL PEIXOTO             BENFICA
# 2    483                           EM CELESTINO SILVA              CENTRO
# 3    476            ESCOLA MUNICIPAL FLORIANO PEIXOTO       SAO CRISTOVAO
# 4    132                            EM PEREIRA PASSOS        RIO COMPRIDO
# ..   ...                                          ...                 ...
# 134  210                   EM DEBORA MENDES DE MORAES  PEDRA DE GUARATIBA
# 135  474                  EM ENGENHEIRO GASTAO RANGEL           GUARATIBA
# 136  301                           EM JONATAS SERRANO           GUARATIBA
# 137  215                            EM NARCISA AMALIA   ILHA DE GUARATIBA
# 138  606                        EM PROFESSOR CASTILHO   ILHA DE GUARATIBA
#
#      latitude  longitude subprefeitura  quantidade_material_didatico  \
# 0   -22.88088  -43.22532        CENTRO                            20
# 1   -22.88957  -43.23620        CENTRO                           121
# 2   -22.90929  -43.18357        CENTRO                           220
# 3   -22.89762  -43.22745        CENTRO                           190
# 4   -22.92441  -43.20857        CENTRO                            67
# ..        ...        ...           ...                           ...
# 134 -23.00141  -43.63875    ZONA OESTE                           570
# 135 -22.98046  -43.64354    ZONA OESTE                           320
# 136 -22.95316  -43.57740    ZONA OESTE                           335
# 137 -23.00908  -43.53758    ZONA OESTE                             0
# 138 -22.99412  -43.59368    ZONA OESTE                           521
#
#                   logradouro_entrega numero tipo_escola
# 0                   RUA CARLOS SEIDL    SN         CIEP
# 1                          RUA EBANO    187          EM
# 2                    RUA DO LAVRADIO     56          EM
# 3                    PRACA ARGENTINA     20          EM
# 4    PRACA CONDESSA PAULO DE FRONTIN     45          EM
# ..                               ...    ...         ...
# 134          RUA BELCHIOR DA FONSECA    643          EM
# 135               ESTRADA DO MAGARCA   9183          EM
# 136             ESTRADA DO MATO ALTO    SN           EM
# 137     ESTRADA TEODORETO DE CAMARGO    SN           EM
# 138                CAMINHO DA MATRIZ   4406          EM
#
# [139 rows x 10 columns]

# %%
df_final['quantidade_material_didatico'].unique()
# Out:
# array([ 20, 121, 220, 190,  67,  48,  92, 578, 591, 473, 456, 223, 420,
#        573,   0, 516, 319, 308, 111, 525, 445, 164, 293, 399, 185, 576,
#         63, 491, 336, 159, 342, 262, 440, 365, 183,  44, 109, 350, 255,
#        457, 493, 489, 504, 530, 158, 123, 468, 234,  24, 151, 564,  61,
#        426, 167, 509, 292, 210, 153, 561, 180, 257, 260, 317, 345, 513,
#        416, 352, 393, 136, 115, 534, 152, 430, 466,  51,  26,  94, 128,
#        520, 392, 279, 161, 179, 194, 599, 315, 435, 400, 148, 269, 571,
#        235, 187, 362,  71, 221, 372, 479,  99, 157, 296, 330, 316, 106,
#        207, 459, 537, 162, 579, 517, 135, 341, 329, 570, 320, 335, 521])

# %%
# Reorganizando as colunas
df_final = df_final[['id', 'nome_escola', 'tipo_escola', 'logradouro_entrega', 'numero', 'bairro', 'subprefeitura', 'latitude', 'longitude', 'quantidade_material_didatico']]

df_final
# Out:
#       id                                  nome_escola tipo_escola  \
# 0    178  CENTRO INTEGRADO DE EDUCACAO PUBLICA HENFIL        CIEP
# 1    634                   EM ALICE DO AMARAL PEIXOTO          EM
# 2    483                           EM CELESTINO SILVA          EM
# 3    476            ESCOLA MUNICIPAL FLORIANO PEIXOTO          EM
# 4    132                            EM PEREIRA PASSOS          EM
# ..   ...                                          ...         ...
# 134  210                   EM DEBORA MENDES DE MORAES          EM
# 135  474                  EM ENGENHEIRO GASTAO RANGEL          EM
# 136  301                           EM JONATAS SERRANO          EM
# 137  215                            EM NARCISA AMALIA          EM
# 138  606                        EM PROFESSOR CASTILHO          EM
#
#                   logradouro_entrega numero              bairro subprefeitura  \
# 0                   RUA CARLOS SEIDL    SN                 CAJU        CENTRO
# 1                          RUA EBANO    187             BENFICA        CENTRO
# 2                    RUA DO LAVRADIO     56              CENTRO        CENTRO
# 3                    PRACA ARGENTINA     20       SAO CRISTOVAO        CENTRO
# 4    PRACA CONDESSA PAULO DE FRONTIN     45        RIO COMPRIDO        CENTRO
# ..                               ...    ...                 ...           ...
# 134          RUA BELCHIOR DA FONSECA    643  PEDRA DE GUARATIBA    ZONA OESTE
# 135               ESTRADA DO MAGARCA   9183           GUARATIBA    ZONA OESTE
# 136             ESTRADA DO MATO ALTO    SN            GUARATIBA    ZONA OESTE
# 137     ESTRADA TEODORETO DE CAMARGO    SN    ILHA DE GUARATIBA    ZONA OESTE
# 138                CAMINHO DA MATRIZ   4406   ILHA DE GUARATIBA    ZONA OESTE
#
#      latitude  longitude  quantidade_material_didatico
# 0   -22.88088  -43.22532                            20
# 1   -22.88957  -43.23620                           121
# 2   -22.90929  -43.18357                           220
# 3   -22.89762  -43.22745                           190
# 4   -22.92441  -43.20857                            67
# ..        ...        ...                           ...
# 134 -23.00141  -43.63875                           570
# 135 -22.98046  -43.64354                           320
# 136 -22.95316  -43.57740                           335
# 137 -23.00908  -43.53758                             0
# 138 -22.99412  -43.59368                           521
#
# [139 rows x 10 columns]

# %%
# Removendo linhas duplicadas e atualizar o DataFrame
df_final = df_final.drop_duplicates()

# Redefinindo o index do DataFrame
df_final = df_final.reset_index(drop=True)

df_final
# Out:
#       id                                  nome_escola tipo_escola  \
# 0    178  CENTRO INTEGRADO DE EDUCACAO PUBLICA HENFIL        CIEP
# 1    634                   EM ALICE DO AMARAL PEIXOTO          EM
# 2    483                           EM CELESTINO SILVA          EM
# 3    476            ESCOLA MUNICIPAL FLORIANO PEIXOTO          EM
# 4    132                            EM PEREIRA PASSOS          EM
# ..   ...                                          ...         ...
# 132  210                   EM DEBORA MENDES DE MORAES          EM
# 133  474                  EM ENGENHEIRO GASTAO RANGEL          EM
# 134  301                           EM JONATAS SERRANO          EM
# 135  215                            EM NARCISA AMALIA          EM
# 136  606                        EM PROFESSOR CASTILHO          EM
#
#                   logradouro_entrega numero              bairro subprefeitura  \
# 0                   RUA CARLOS SEIDL    SN                 CAJU        CENTRO
# 1                          RUA EBANO    187             BENFICA        CENTRO
# 2                    RUA DO LAVRADIO     56              CENTRO        CENTRO
# 3                    PRACA ARGENTINA     20       SAO CRISTOVAO        CENTRO
# 4    PRACA CONDESSA PAULO DE FRONTIN     45        RIO COMPRIDO        CENTRO
# ..                               ...    ...                 ...           ...
# 132          RUA BELCHIOR DA FONSECA    643  PEDRA DE GUARATIBA    ZONA OESTE
# 133               ESTRADA DO MAGARCA   9183           GUARATIBA    ZONA OESTE
# 134             ESTRADA DO MATO ALTO    SN            GUARATIBA    ZONA OESTE
# 135     ESTRADA TEODORETO DE CAMARGO    SN    ILHA DE GUARATIBA    ZONA OESTE
# 136                CAMINHO DA MATRIZ   4406   ILHA DE GUARATIBA    ZONA OESTE
#
#      latitude  longitude  quantidade_material_didatico
# 0   -22.88088  -43.22532                            20
# 1   -22.88957  -43.23620                           121
# 2   -22.90929  -43.18357                           220
# 3   -22.89762  -43.22745                           190
# 4   -22.92441  -43.20857                            67
# ..        ...        ...                           ...
# 132 -23.00141  -43.63875                           570
# 133 -22.98046  -43.64354                           320
# 134 -22.95316  -43.57740                           335
# 135 -23.00908  -43.53758                             0
# 136 -22.99412  -43.59368                           521
#
# [137 rows x 10 columns]

# %%
# Checking for duplicates in lat and lon to avoid disturbing our calculations


duplicates = df_final[df_final.duplicated(subset=['latitude', 'longitude'])].shape[0]
print(f'Duplicates in our df: {duplicates}')

df_final = df_final.drop_duplicates(subset=['latitude', 'longitude'], keep='first')

duplicates = df_final[df_final.duplicated(subset=['latitude', 'longitude'])].shape[0]
print(f'After removing them: {duplicates}')
# Out:
# Duplicates in our df: 2
# After removing them: 0

# %% [markdown]
# subprefeituras

# %%
from geopy.distance import geodesic

def distance(point1, point2):
    if point1 == point2:
        return 0.0
    return geodesic(point1, point2).km

# %%
def nearest_neighbor(points):
    unvisited = set(range(1, len(points)))  # índices que representam os pontos não visitados
    current_point = 0
    route = [current_point]
    total_distance = 0  # Inicializa a distância total

    while unvisited:
        nearest = min(unvisited, key=lambda x: distance(points[current_point], points[x]))
        total_distance += distance(points[current_point], points[nearest])  # Atualiza a distância total
        print(f"A distância até o ponto {nearest} é {total_distance} km")  # Mostra a distância até o momento
        route.append(nearest)
        unvisited.remove(nearest)
        current_point = nearest

    total_distance += distance(points[current_point], points[0])  # Adiciona a distância de volta ao ponto inicial
    print("Distância total percorrida: ", total_distance, "km")
    return route


# Converter seu DataFrame em uma lista de pontos
pontos_entrega = list(zip(df_final['latitude'], df_final['longitude']))

# Encontrar a melhor rota
best_route = nearest_neighbor(pontos_entrega)
print("Melhor rota:", best_route)

best_route
# Out:
# A distância até o ponto 1 é 1.473919351961161 km
# A distância até o ponto 8 é 2.473369242574117 km
# A distância até o ponto 3 é 3.5344256154924043 km
# A distância até o ponto 28 é 5.3581454708113565 km
# A distância até o ponto 29 é 6.173707824802353 km
# A distância até o ponto 21 é 7.21392136311456 km
# A distância até o ponto 27 é 8.211325870559076 km
# A distância até o ponto 26 é 8.781014877550138 km
# A distância até o ponto 25 é 10.292444937616152 km
# A distância até o ponto 22 é 11.72627448697503 km
# A distância até o ponto 24 é 13.118183052218845 km
# A distância até o ponto 40 é 14.859488435696314 km
# A distância até o ponto 42 é 15.924628358023401 km
# A distância até o ponto 48 é 17.039105449738194 km
# A distância até o ponto 44 é 17.922405808145136 km
# A distância até o ponto 49 é 18.409972576936838 km
# A distância até o ponto 63 é 19.925825687948546 km
# A distância até o ponto 61 é 21.687935118707788 km
# A distância até o ponto 58 é 22.99525602832749 km
# A distância até o ponto 62 é 23.750970711323443 km
# A distância até o ponto 60 é 24.830299956539893 km
# A distância até o ponto 56 é 25.88020551401007 km
# A distância até o ponto 52 é 26.618236129994095 km
# A distância até o ponto 57 é 28.333516272096297 km
# A distância até o ponto 54 é 29.502013598368162 km
# A distância até o ponto 55 é 30.684396916804104 km
# A distância até o ponto 59 é 31.571481142377134 km
# A distância até o ponto 51 é 33.69243845264056 km
# A distância até o ponto 73 é 34.866972807479506 km
# A distância até o ponto 75 é 36.43529817501149 km
# A distância até o ponto 46 é 39.09791403773292 km
# A distância até o ponto 50 é 41.5191254649294 km
# A distância até o ponto 65 é 43.13175341237114 km
# A distância até o ponto 81 é 46.42760610496392 km
# A distância até o ponto 78 é 47.718088547580464 km
# A distância até o ponto 72 é 48.82447834730724 km
# A distância até o ponto 77 é 50.216336595346945 km
# A distância até o ponto 64 é 51.05015116277001 km
# A distância até o ponto 79 é 51.933365936103655 km
# A distância até o ponto 90 é 54.12834938665766 km
# A distância até o ponto 80 é 57.96060813924396 km
# A distância até o ponto 101 é 60.2799654325209 km
# A distância até o ponto 71 é 61.723550995333724 km
# A distância até o ponto 69 é 64.32296214461 km
# A distância até o ponto 70 é 65.43600322651781 km
# A distância até o ponto 68 é 68.71404785429917 km
# A distância até o ponto 99 é 76.56321548013489 km
# A distância até o ponto 76 é 77.51614091090751 km
# A distância até o ponto 104 é 78.83664585773481 km
# A distância até o ponto 106 é 80.08107007829 km
# A distância até o ponto 107 é 82.6955885166258 km
# A distância até o ponto 89 é 86.79544435025058 km
# A distância até o ponto 93 é 89.83914056086849 km
# A distância até o ponto 92 é 91.92323717209871 km
# A distância até o ponto 82 é 93.58207914415549 km
# A distância até o ponto 83 é 95.22296387760385 km
# A distância até o ponto 91 é 97.71432298883173 km
# A distância até o ponto 88 é 98.33427730922575 km
# A distância até o ponto 94 é 99.41114036521434 km
# A distância até o ponto 85 é 104.46256077280583 km
# A distância até o ponto 31 é 110.88290060824887 km
# A distância até o ponto 30 é 114.6589140029836 km
# A distância até o ponto 33 é 116.98807023735706 km
# A distância até o ponto 16 é 117.3445832529875 km
# A distância até o ponto 5 é 118.84326400335607 km
# A distância até o ponto 14 é 120.233689989605 km
# A distância até o ponto 13 é 121.29653872828138 km
# A distância até o ponto 18 é 123.36336841537202 km
# A distância até o ponto 12 é 125.01074001146806 km
# A distância até o ponto 20 é 125.88955719621362 km
# A distância até o ponto 11 é 127.20700657772409 km
# A distância até o ponto 2 é 128.85969802997386 km
# A distância até o ponto 6 é 129.93337247161816 km
# A distância até o ponto 7 é 130.9308009572409 km
# A distância até o ponto 23 é 132.815833725475 km
# A distância até o ponto 9 é 133.01412976172827 km
# A distância até o ponto 4 é 133.84865874980477 km
# A distância até o ponto 19 é 137.09883827101282 km
# A distância até o ponto 17 é 138.05179405948968 km
# A distância até o ponto 10 é 139.13725162685114 km
# A distância até o ponto 37 é 147.77051370853638 km
# A distância até o ponto 38 é 150.3567757258448 km
# A distância até o ponto 32 é 151.7007417935084 km
# A distância até o ponto 43 é 153.30153401928754 km
# A distância até o ponto 45 é 153.87449255252685 km
# A distância até o ponto 47 é 154.7827483991357 km
# A distância até o ponto 34 é 155.74647937470047 km
# A distância até o ponto 41 é 156.85508649183998 km
# A distância até o ponto 36 é 158.2811989166579 km
# A distância até o ponto 35 é 159.66080116455504 km
# A distância até o ponto 39 é 161.05342781804455 km
# A distância até o ponto 74 é 164.52208113182508 km
# A distância até o ponto 67 é 177.29689401613336 km
# A distância até o ponto 66 é 180.2293565159493 km
# A distância até o ponto 15 é 186.8535197561294 km
# A distância até o ponto 100 é 215.74287202796376 km
# A distância até o ponto 103 é 217.0339041527346 km
# A distância até o ponto 102 é 218.56989012279737 km
# A distância até o ponto 105 é 219.8929180021337 km
# A distância até o ponto 97 é 223.14996425390152 km
# A distância até o ponto 98 é 223.7438663228048 km
# A distância até o ponto 95 é 225.07632092169442 km
# A distância até o ponto 96 é 229.1351129961056 km
# A distância até o ponto 113 é 236.39795983910363 km
# A distância até o ponto 109 é 239.5799281901719 km
# A distância até o ponto 116 é 243.6867964646309 km
# A distância até o ponto 108 é 245.81470843524465 km
# A distância até o ponto 115 é 248.4354457780039 km
# A distância até o ponto 53 é 250.4866007340509 km
# A distância até o ponto 110 é 252.4435960404889 km
# A distância até o ponto 114 é 253.20501815767838 km
# A distância até o ponto 111 é 256.41855857031715 km
# A distância até o ponto 121 é 258.73166197506526 km
# A distância até o ponto 126 é 260.86430127861087 km
# A distância até o ponto 117 é 261.9123746023951 km
# A distância até o ponto 119 é 264.27426502186705 km
# A distância até o ponto 123 é 264.9090210107697 km
# A distância até o ponto 120 é 266.4347721748042 km
# A distância até o ponto 127 é 270.12852977286735 km
# A distância até o ponto 122 é 272.181466894527 km
# A distância até o ponto 129 é 275.04400154779773 km
# A distância até o ponto 128 é 277.3967585314912 km
# A distância até o ponto 131 é 278.20980096543485 km
# A distância até o ponto 130 é 280.58129542802914 km
# A distância até o ponto 134 é 285.27205833437046 km
# A distância até o ponto 132 é 290.1055561905579 km
# A distância até o ponto 112 é 296.97641916638855 km
# A distância até o ponto 87 é 304.0346620281079 km
# A distância até o ponto 84 é 308.3735313730078 km
# A distância até o ponto 133 é 314.22182386538526 km
# A distância até o ponto 86 é 327.92187196907514 km
# A distância até o ponto 125 é 352.7826783074667 km
# A distância até o ponto 118 é 354.78637568901866 km
# A distância até o ponto 124 é 358.0193331598983 km
# Distância total percorrida:  402.0963804088896 km
# Melhor rota: [0, 1, 8, 3, 28, 29, 21, 27, 26, 25, 22, 24, 40, 42, 48, 44, 49, 63, 61, 58, 62, 60, 56, 52, 57, 54, 55, 59, 51, 73, 75, 46, 50, 65, 81, 78, 72, 77, 64, 79, 90, 80, 101, 71, 69, 70, 68, 99, 76, 104, 106, 107, 89, 93, 92, 82, 83, 91, 88, 94, 85, 31, 30, 33, 16, 5, 14, 13, 18, 12, 20, 11, 2, 6, 7, 23, 9, 4, 19, 17, 10, 37, 38, 32, 43, 45, 47, 34, 41, 36, 35, 39, 74, 67, 66, 15, 100, 103, 102, 105, 97, 98, 95, 96, 113, 109, 116, 108, 115, 53, 110, 114, 111, 121, 126, 117, 119, 123, 120, 127, 122, 129, 128, 131, 130, 134, 132, 112, 87, 84, 133, 86, 125, 118, 124]
# [0,
#  1,
#  8,
#  3,
#  28,
#  29,
#  21,
#  27,
#  26,
#  25,
#  22,
#  24,
#  40,
#  42,
#  48,
#  44,
#  49,
#  63,
#  61,
#  58,
#  62,
#  60,
#  56,
#  52,
#  57,
#  54,
#  55,
#  59,
#  51,
#  73,
#  75,
#  46,
#  50,
#  65,
#  81,
#  78,
#  72,
#  77,
#  64,
#  79,
#  90,
#  80,
#  101,
#  71,
#  69,
#  70,
#  68,
#  99,
#  76,
#  104,
#  106,
#  107,
#  89,
#  93,
#  92,
#  82,
#  83,
#  91,
#  88,
#  94,
#  85,
#  31,
#  30,
#  33,
#  16,
#  5,
#  14,
#  13,
#  18,
#  12,
#  20,
#  11,
#  2,
#  6,
#  7,
#  23,
#  9,
#  4,
#  19,
#  17,
#  10,
#  37,
#  38,
#  32,
#  43,
#  45,
#  47,
#  34,
#  41,
#  36,
#  35,
#  39,
#  74,
#  67,
#  66,
#  15,
#  100,
#  103,
#  102,
#  105,
#  97,
#  98,
#  95,
#  96,
#  113,
#  109,
#  116,
#  108,
#  115,
#  53,
#  110,
#  114,
#  111,
#  121,
#  126,
#  117,
#  119,
#  123,
#  120,
#  127,
#  122,
#  129,
#  128,
#  131,
#  130,
#  134,
#  132,
#  112,
#  87,
#  84,
#  133,
#  86,
#  125,
#  118,
#  124]

# %%
df_final['subprefeitura'].unique()

# %%
# Usando a função groupby para calcular a quantidade total de material por subprefeitura
df_sub_final = df_final.groupby('subprefeitura')['quantidade_material_didatico'].sum().reset_index()

df_sub_final

# %%
# Ordenando o DataFrame com base na coluna 'melhor_rota'
df_final = df_final.sort_values(by='subprefeitura')

# Redefinindo o índice do DataFrame para refletir a nova ordenação
df_final = df_final.reset_index(drop=True)
df_final

# %% [markdown]
# melhor_rota

# %%
# Função para encontrar a rota mais curta usando o algoritmo do vizinho mais próximo
def nearest_neighbor(points):
    unvisited = set(range(1, len(points)))  # índices que representam os pontos não visitados
    current_point = 0
    route = [current_point]

    while unvisited:
        nearest = min(unvisited, key=lambda x: distance(points[current_point], points[x]))
        route.append(nearest)
        unvisited.remove(nearest)
        current_point = nearest

    route.append(0)  # Volta ao ponto inicial para fechar o ciclo
    return route

# Converter seu DataFrame em uma lista de pontos
pontos_entrega = list(zip(df_final['latitude'], df_final['longitude']))

# Encontrar a melhor rota
best_route = nearest_neighbor(pontos_entrega)
print("Melhor rota:", best_route)

best_route

# %%
# Eliminando o valor 0 da última linha de 'best_route'
best_route = best_route[:-1]

# %%
pontos_entrega

# %%
# Criando a coluna 'melhor_rota' no DataFrame
df_final['melhor_rota'] = best_route

df_final

# %% [markdown]
# reordenando

# %%
# Ordenando o DataFrame com base na coluna 'melhor_rota'
df_final_re = df_final.sort_values(by='melhor_rota')

# Redefinindo o índice do DataFrame para refletir a nova ordenação
df_final_re = df_final_re.reset_index(drop=True)
df_final_re

# %%
df_final

# %% [markdown]
# export

# %%
# Exportando os DataFrames
df_final_re.to_csv('rotas_entrega.csv', index=False)

df_sub_final.to_csv('quantidade_por_subprefeitura.csv', index=False)

# %% [markdown]
# # Desafio

# %%
import matplotlib.pyplot as plt
import numpy as np

# Extraindo as latitudes e longitudes das escolas
latitudes = df_final['latitude'].astype(float)
longitudes = df_final['longitude'].astype(float)

# Normalizando a quantidade de material para o tamanho do ponto
tamanho_ponto = df_final['quantidade_material_didatico'] / df_final['quantidade_material_didatico'].max() * 300

# Definindo intervalos para a quantidade de material
quantidade_intervalos = [0, 100, 200, 300, np.inf]
rotulos_legenda = ['0-100', '101-200', '201-300', '300+']

# Criando um gráfico de dispersão (scatter plot) para os pontos das escolas com gradiente de cor
plt.figure(figsize=(10, 8))

for i in range(len(latitudes)):
    plt.scatter(
        longitudes[i],
        latitudes[i],
        marker='o',
        color=plt.cm.Blues(tamanho_ponto[i] / tamanho_ponto.max()),
        s=tamanho_ponto[i],
        label=f'{df_final["quantidade_material_didatico"].iloc[i]}'
    )

    # Ajustando a posição do rótulo
    deslocamento_vertical = 0.005
    deslocamento_horizontal = -0.001
    plt.annotate(
        df_final['quantidade_material_didatico'].iloc[i],
        (longitudes[i] + deslocamento_horizontal, latitudes[i] + deslocamento_vertical),
        fontsize=12
    )

# Traçando a rota com base na melhor_rota
melhor_rota = df_final['melhor_rota'].tolist()
rota_latitudes = latitudes[melhor_rota]
rota_longitudes = longitudes[melhor_rota]

# Criando o gráfico de dispersão (scatter plot) para a rota com gradiente de cor
plt.plot(
    rota_longitudes,
    rota_latitudes,
    linestyle='-',
    marker='o',
    color='red',
    label='Rota'
)

# Definindo rótulos para os eixos
plt.xlabel('Longitude')
plt.ylabel('Latitude')

# Adicionando título ao gráfico
plt.title('Rota Otimizada de Entrega')

# Criando legenda com cores representando os intervalos de quantidade de material
legendas_por_intervalo = []

for i in range(len(quantidade_intervalos) - 1):
    cor = plt.cm.Blues((quantidade_intervalos[i] + quantidade_intervalos[i + 1]) / (2 * df_final['quantidade_material_didatico'].max()))
    legenda = f'{quantidade_intervalos[i]}-{quantidade_intervalos[i + 1]}' if quantidade_intervalos[i + 1] < np.inf else f'{quantidade_intervalos[i]}+'
    legendas_por_intervalo.append(plt.Line2D([0], [0], marker='o', color=cor, label=legenda, markersize=10, linestyle=''))

legendas_por_intervalo.append(plt.Line2D([0], [0], marker='o', color='red', label='Rota', markersize=10, linestyle='-'))

plt.legend(handles=legendas_por_intervalo, title='Quantidade de Material Didático')

# Exibindo o gráfico
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:2263, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:2273, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 68
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[54], line 20
#      16 plt.figure(figsize=(10, 8))
#      18 for i in range(len(latitudes)):
#      19     plt.scatter(
# ---> 20         longitudes[i],
#      21         latitudes[i],
#      22         marker='o',
#      23         color=plt.cm.Blues(tamanho_ponto[i] / tamanho_ponto.max()),
#      24         s=tamanho_ponto[i],
#      25         label=f'{df_final["quantidade_material_didatico"].iloc[i]}'
#      26     )
#      28     # Ajustando a posição do rótulo
#      29     deslocamento_vertical = 0.005
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:981, in Series.__getitem__(self, key)
#     978     return self._values[key]
#     980 elif key_is_scalar:
# --> 981     return self._get_value(key)
#     983 if is_hashable(key):
#     984     # Otherwise index.get_value will raise InvalidIndexError
#     985     try:
#     986         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:1089, in Series._get_value(self, label, takeable)
#    1086     return self._values[label]
#    1088 # Similar to Index.get_value, but we do not fall back to positional
# -> 1089 loc = self.index.get_loc(label)
#    1090 return self.index._get_values_for_loc(self, loc, label)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 68

# %% [markdown]
# extra

# %%
import folium
import networkx as nx

# Criar um gráfico direcionado para representar a rota
G = nx.DiGraph()

# Adicionar arestas com base na melhor_rota
melhor_rota = df_final['melhor_rota'].tolist()
for i in range(len(melhor_rota) - 1):
    origem = melhor_rota[i]
    destino = melhor_rota[i + 1]
    G.add_edge(origem, destino)

# Criar um mapa
m = folium.Map(location=[-22.88, -43.43], zoom_start=12)

# Adicionar marcadores para as escolas com pop-ups personalizados
for index, row in df_final.iterrows():
    pop_up_text = f"<b>{row['nome_escola']}</b><br>"
    pop_up_text += f"Logradouro: {row['logradouro_entrega']}<br>"
    pop_up_text += f"Número: {row['numero']}<br>"
    pop_up_text += f"Bairro: {row['bairro']}<br>"
    pop_up_text += f"Subprefeitura: {row['subprefeitura']}<br>"
    pop_up_text += f"Quantidade de Material: {row['quantidade_material_didatico']}"

    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=folium.Popup(html=pop_up_text, max_width=300),  # Use folium.Popup para pop-ups personalizados
        icon=folium.Icon(color='red', icon=''),
    ).add_to(m)

# Adicionar linhas para a rota
for origem, destino in G.edges():
    origem_lat = df_final.loc[df_final['melhor_rota'] == origem, 'latitude'].values[0]
    origem_lon = df_final.loc[df_final['melhor_rota'] == origem, 'longitude'].values[0]
    destino_lat = df_final.loc[df_final['melhor_rota'] == destino, 'latitude'].values[0]
    destino_lon = df_final.loc[df_final['melhor_rota'] == destino, 'longitude'].values[0]

    folium.PolyLine(
        locations=[(origem_lat, origem_lon), (destino_lat, destino_lon)],
        color='red',
        weight=2
    ).add_to(m)

# Adicionar marcador com a mensagem inicial
initial_message = "Clique sobre o ponto para obter mais informações sobre a entrega"
folium.Marker(
    location=[-22.885, -43.22],  # Posição do marcador
    popup=initial_message,
    icon=folium.Icon(color='blue', icon='info-sign'),
).add_to(m)

# Exibir o mapa
m
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 import folium
#       2 import networkx as nx
#       4 # Criar um gráfico direcionado para representar a rota
#
# ModuleNotFoundError: No module named 'folium'
